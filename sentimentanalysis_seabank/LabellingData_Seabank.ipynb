# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from Textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (4.67.1)

# %%
from textblob import TextBlob

# %%
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/ProsessedSeabank.csv'

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.10/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.12.14)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2025.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)

# %%
# Importing library yang dibutuhkan
import googletrans
from googletrans import Translator

# %%
data = pd.read_csv(data_path)
data.head()
# Out:
#   content_normalisasi2
# 0                bagus
# 1               mantap
# 2     gk saldo minimal
# 3                  oke
# 4               urgent

# %%
translator = Translator()
translations = {}
for column in data.columns:
    # Unique elements of the column
    unique_elements = data[column].unique()
    for element in unique_elements:
        # Adding all the translations to a dictionary (translations)
        translations[element] = translator.translate(element).text
translations
# Out:
# {'bagus': 'Good',
#  'mantap': 'solid',
#  'gk saldo minimal': 'no minimum balance',
#  'oke': 'limit',
#  'urgent': 'urgent',
#  'terima kasih seabank terbaik': 'thank you best seabank',
#  'bayar qris kena x bayar berhasil gagal dana yg terpotong x email c memuaskan udah gak solusi c nya': 'pay qris hit x pay successful fail funds deducted x email c is satisfactory no longer is the solution c',
#  'seabank okcepat': 'seabank okcepat',
#  nan: 'in',
#  'nyaman mudah transfer tarik tunai': 'convenient easy transfer cash withdrawal',
#  'gak ribet transfer kemna aja seabank emang bagus mntap': 'No hassle, transfer anywhere, Seabank is really good',
#  'kali seabank aktifkan seabank pinjam th loh pake seabank th pake shopee ga telat bayar': "Seabank activates seabank loans, you use Seabank, you don't pay late using Shopee",
#  'no coment': 'no comment',
#  'baguss banget': 'very good',
#  'baguss mudah': 'Nice easy',
#  'seabank memank mantaappzz': 'Jayabank Meemonk Mantavj',
#  'memudahkan transaksi': 'make transactions easier',
#  'mudah': 'easy',
#  'good': 'good',
#  'mantap prose cepat delay kena biaya admin': 'Great, fast process, delays are subject to admin fees',
#  'transfer jdi mudah dn murah': 'Transfers are easy and cheap',
#  'mantab praktis': 'practical',
#  'mudah cepat': 'easy fast',
#  'apk bagus': 'good apk',
#  'mudah gampang': 'easy easy',
#  'pake sea bank gak ribet': 'Using Sea Bank is not complicated',
#  'mudah keamanan berlapis': 'easy layered security',
#  'aplikasi nya membantu': 'the application helps',
#  'membatu': 'petrified',
#  'bank digital terbaik': 'best digital bank',
#  'memudahkan': 'facilitate',
#  'cocok umkn': 'suitable for umkm',
#  'versi mengapresiasi kecepatan sea bank nilai terbaik bitang karna kinerjanya sbagai aplikasi perbankan aman nyaman mengapresiasi kinerja c nya detail kendala menyelesaikan nya dngan menyarankan fitur bayar berbayarnya tolong tambahin fitur isi ulang kartu etoll aplikasi': "The version appreciates the speed of Sea Bank, the best value for Bitang because of its performance as a safe and comfortable banking application. Appreciates its C performance. Details of problems in solving it by suggesting a paid payment feature. Please add the application's ETOLL card top-up feature.",
#  'keren bosku': 'cool boss',
#  'layanan sekalirespon cepatbiaya transfer gratis terimakasih sea bank': 'Very fast response service, free transfer fees, thank you Seabank',
#  'nice app': 'nice app',
#  'benefit bagus': 'good benefits',
#  'gunanya tertera limit pinjaman ujungnya gagal pencairan ga pinjaman lancar gak telat gak menjamin next ambil taunya berhasil limit pinjaman tertera tersedia kecewa': "The point is that the loan limit is listed, in the end the disbursement fails, the loan doesn't go smoothly, it's not late, it doesn't guarantee that next time you will take it, it will be successful, the loan limit listed is available, disappointed",
#  'mudah ribettransaksi cepat kalangan tdk bertele²': 'easy and complicated, fast transactions without long-winded groups',
#  'mantapp': 'strong',
#  'satttt setttt nga ribet biaya admin mantap pokoknyaaa': "OK, it's not a hassle with admin fees, it's really great",
#  'bagus satset': 'nice satset',
#  'aplikasi bagus ngebut': 'good app speeding',
#  'cpt mdh': 'cpt mdh',
#  'memuaskan bayar mudah': 'easy pay satisfaction',
#  'mantap cpat': 'very fast',
#  'is the bess': 'is the bess',
#  'senang bangat si krn tabungan berbunga': "I'm really happy because the savings are interest-bearing",
#  'seabank menarik ribetsemoga menampung seabank': 'seabank is interesting, hopefully it will accommodate seabank',
#  'bagus praktis mudah coba tarik tunai outlet menarik': 'good, practical, easy, try withdrawing cash at interesting outlets',
#  'gratis ongkir': 'free shipping',
#  'mudah aman': 'easy safe',
#  'membantu': 'help',
#  'senang': 'like',
#  'alhmdllh kendala terkadang suka wa keamanan nya': 'Alhamdllh the problem is sometimes I like the security',
#  'mudah cpt': 'easy cpt',
#  'skrg top up e wallet kena charg malas gunain aplikasi': 'now top up e wallet charged lazy to use the application',
#  'menguntungkan mantap': 'steady profit',
#  'fitur pinjam seabank': 'seabank loan feature',
#  'suka banget': 'really like',
#  'so easy': 'so easy',
#  'transaksi aman nyaman seabank aj': 'transactions are safe and secure',
#  'apk yg berguna': 'useful apk',
#  'rekomen': 'recommend',
#  'tambahin kartu debitkredit': 'add a debit credit card',
#  'seabank the best': 'seabank the best',
#  'sebagi pengguna membantu dlm transaksi': 'as a user assists in transactions',
#  'gangguan kadang pencet ikon transfer': 'The problem is sometimes pressing the transfer icon',
#  'seabank bagus keren unik': 'seabank nice cool unique',
#  'keren': 'keren',
#  'bebas admin gk ribet': 'admin free, no hassle',
#  'sy susah masuk kembaliharus hapus data dl masuk klo tidaklayar sj putih kosong aja tungguin sampe berubah': "I'm having trouble logging in again, I have to delete the data when I log in. If not, the screen is just blank white, just wait until it changes.",
#  'mudah cepat bunga': 'easy to flower',
#  'ok': 'ok',
#  'bermanfaat': 'beneficial',
#  'mantap cepat terimakasih': 'great, fast, thank you',
#  'bank digital terbaik pakai insyaallah aman': 'the best digital bank to use, God willing, safe',
#  'gokil abis': "it's really crazy",
#  'tampilan simplemudah': 'simple appearance',
#  'aplikasi sea bank jelek ya gak klik apapun tf ga pdhl udah update udah matiin hp tp ttp aja gak nnti klo udah auto amanin saldo aja deh takut ga ambil': "The sea bank app is bad, it doesn't click anything but it doesn't even update, I turn off the phone but it still doesn't wait, if it's on auto, just secure the balance, I'm afraid I won't take it",
#  'mudah lancar banget': 'very easy and smooth',
#  'bagus bebas biaya admin': 'good, no admin fees',
#  'mantap mudah simpel ribet': 'great, easy, simple and complicated',
#  'membantubanyak untung nya': 'helps a lot of profit',
#  'aplikasi nya mudah tp kalo transfer sulit memuat tulisannya stlah coba muat ulang pakai tp transaksi stlah tdk tolong diperbaiki sistemnya pengguna seabank': "easy application but if the transfer is difficult to load the text is wrong try reloading using it but the transaction doesn't work please fix the system seabank users",
#  'lancar': 'fluent',
#  'mantappp': 'greatpp',
#  'simpel mantap': 'simple, great',
#  'mantap menguntungkan nasabah': 'steadily benefiting customers',
#  'tingkatkan': 'increase',
#  'bagus apknya mantaaap': 'good, the cellphone is solid',
#  'mempermudah akses': 'makes access easier',
#  'aplikasinya sangga berguna saggat bagus': 'the application is very useful very good',
#  'ok ship': 'ok ship',
#  'recomend': 'recomend',
#  'mantap thanks': 'great, thanks',
#  'good bangett pokonya': 'really good',
#  'mudah kuota x gratisbln untk transaksi banksangat membantu': 'Easy free monthly XL quota for bank transactions is very helpful',
#  'tolong sediakan pay leter ny': 'please provide the paylater',
#  'enak banget': 'very delicious',
#  'pake aplikasi bagus dana gopay mobile tinggalkan aplikasi ganti hp aplikasi yg udah pindah hp aplikasi gak bangsatnya verifikasi wajah suruh telp c boro boro tlp c langsung nyelesaikan permasalahan nunggu harian itupun ato login php c team gak c': 'use a good application, gopay mobile funds, leave the application, replace the cellphone, the application that has moved the cellphone, the application is not bad, face verification, tell me to call C, Boro Boro, Call C, immediately solves the daily waiting problem, or even login to PHP C Team, no C',
#  'amazed': 'amazed',
#  'penggunaan mudah aman': 'safe easy use',
#  'pemula semoga menyenangkan': 'beginners have fun',
#  'bintang berubah karna aplikasi nya gk tau transfer aja susahdi tekan tekan gk bisase olah olah respontolong tingkat uninstall': "the star changed because the application doesn't know how to transfer it's hard to press it can't process the response please uninstall rate",
#  'memuaskan': 'satisfactory',
#  'mudah digunankan nyaman suku bunga lumayan': 'easy to use, comfortable, decent interest rates',
#  'persentase': 'percentage',
#  'seabank customer servicena slowrespin bangetharusnya c siaga jam': 'seabank customer service is really slow response, you should be on standby at the clock',
#  'aplikasi macet operasi': 'application crashes operation',
#  'bagus banget aplikasi canggih': 'really good sophisticated application',
#  'mantap ka': "you're steady",
#  'pelayanannya': 'his service',
#  'fast respon': 'fast respon',
#  'mudah transaksi': 'easy transaction',
#  'memuaskan pelayanan aplikasi tampilannya menarikdan kecepatannya stabil d versi yg skrg': 'satisfactory service, the application looks attractive and the speed is stable in the current version',
#  'transaksi cepat dn gratis yg utama': 'The main thing is fast and free transactions',
#  'nice': 'nice',
#  'gajelas': 'not clear',
#  'bagus pokok dah': 'good tree already',
#  'mantap gratis x tf bank': 'great free x tf bank',
#  'semoga kedepandan': 'hopefully in the future',
#  'transaksi aman transfer kemana gratis pungut biyaya admin pake transaksi': 'secure transactions, transfer anywhere, free of charge admin fees using transactions',
#  'mantap transaksinya cepat banget amanah suka': 'great, very fast transaction, trustworthy, like it',
#  'mudah efektif': 'easy effective',
#  'mntap': 'mntap',
#  'mantap biaya tf': 'steady tf fees',
#  'terbaik': 'the best',
#  'menyenangkangk ribet': "it's fun and complicated",
#  'bebas admin': 'admin free',
#  'memper mudah bertransaksi': 'make transactions easier',
#  'lancar jaya menurutku patut diapresiasi kecepatan kenyamannya bertransaksi suka banget menggunakannya menurutku aplikasi ssbagai menabung mencari keamanan dana aplikasinya bagus keperluan seahari fitur bayar berbayaranya aplikasi men free biaya admin transaksi transfer smua bank cocok keperluan bisnis mngkin sekian dlu smogah komentarku membantu': "smoothly and successfully, in my opinion, it is worth appreciating the speed of transactions, the convenience of making transactions, I really like using it. In my opinion, the application is for saving, looking for security of funds, the application is good for daily needs, the paid payment feature, the application is free of admin fees, all bank transfer transactions are suitable for business needs, maybe that's all for now, I hope my comments help",
#  'sea bank is perfect bank': 'sea bank is perfect bank',
#  'membantu prose nya cepat': 'helps make the process fast',
#  'transaksi susah benerrrr hah kali loh bayar transfer gak haduuhhh uang jualan shopee masuknya kesini ngambil aja masak sihhh jam gitu aplikasi transaksi heran gw': "Transactions are really difficult hah, you know, paying for transfers doesn't matter, Shopee sales money comes in here, just pick it up and cook, at that time, the transaction application surprised me.",
#  'apk mmbntu transaksi': 'apk helps transactions',
#  'sippp': 'sippp',
#  'puas': 'damage',
#  'membantu pelayanan terbaik': 'help with the best service',
#  'cepet bagus': 'fast, good',
#  'efisien': 'efficient',
#  'bagus cepat': 'good fast',
#  'bagus mudah transaksi': 'good, easy transaction',
#  'hot': 'hot',
#  'mntp fitur nya lengkapp': 'great, complete features',
#  'buruk': 'bad',
#  'terimakasih bantuannya': 'thanks for the help',
#  'cepat praktis': 'fast and practical',
#  'menyenangkan': 'pleasant',
#  'mantap seabank': 'great seabank',
#  'mohon buatkan kantong deposito minimal dibawah rb': 'Please create a minimum deposit bag below Rp',
#  'sgt cpat': 'very fast',
#  'akun seabank pindahkan hp verifikasi wajah': 'seabank account move phone face verification',
#  'log in suruh scan ktp nik terdaftar akun berhasil knp gini ga solusinya hapus akun jg ga gimana si': "log in, tell me to scan my ID card, register the account, it works, why doesn't it work, the solution is to delete the account, what do you do?",
#  'aplikasi susah bgt daftar': 'the application is very difficult to register',
#  'aplikasi bagus': 'good app',
#  'lumayan': 'reasonable',
#  'sea bank mantap bintang ya': 'Sea Bank is a great star',
#  'mantap apk ringan ui ribet': 'great, light apk, complicated UI',
#  'matappp': 'matappp',
#  'kalo transfer susah banget tulisannya nyusahin banget tolong benerin': 'If the transfer is really difficult, the writing is really troublesome, please fix it',
#  'bagus bgt gk ribet tpi aman': 'Very good, not complicated but safe',
#  'mantap semoga aplikasi seabank dana pinjaman penggunanya': 'Great, hopefully the Seabank application will provide loan funds to its users',
#  'biaya tarik tunai setor tunai ribu': 'cash withdrawal fee cash deposit thousand',
#  'mudah menguntungkan': 'easy to profit',
#  'sea bank membantu': 'seabank helps',
#  'cepat mudah': 'quick easy',
#  'bagus cepat transaksi terima kasih': 'good fast transaction thank you',
#  'cocok orangmenguntungkan': 'suitable for profitable people',
#  'seabank transaksi terbaik': 'seabank best transaction',
#  'alhamdulillah': 'thank god',
#  'transaksi mudah belanja shoope tf bank ewallet': 'Easy shopping transactions on Shopee TF Bank ewallet',
#  'enaken': 'to me',
#  'rmantap': 'steady',
#  'seabank error kah gak transfer': 'Seabank error, no transfer',
#  'prose cepatmudah gratis biaya kirim': 'fast, easy process, free shipping',
#  'puas mudah thanks seabank': 'easily satisfied, thanks seabank',
#  'rekomendate': 'recommended',
#  'keren bet': 'return bet',
#  'ter best': 'ter best',
#  'developer tolong update pembaruan kog fitur transfer ngk ngk transfer uang': "Developer please update the update why the transfer feature won't transfer money",
#  'bagus mudah cepat gratis': 'good easy fast free',
#  'memudahkan pelayanan makasih seabank': 'makes service easier, thank you Seabank',
#  'lancar cepet aplikasi nya eror ga kecewa banget': "smoothly, quickly, the application errored, I wasn't really disappointed",
#  'top markotop': 'top markotope',
#  'aman': 'aman',
#  'transfer dana lg susah ya knp ya': 'Transferring funds is still difficult, why?',
#  'membantudan bagus transaksi transfer gratis': 'helpful and good free transfer transactions',
#  'mudah amanah cocok penguna': 'easy, trustworthy, suitable for users',
#  'yg menyodorkan pinjaman yg mengatasnamakan seabank': 'who provided loans in the name of Seabank',
#  'aplikasi bagussangat puas seabank': 'good applicationvery satisfied seabank',
#  'terpercaya': 'trustworthy',
#  'aplikasi bermanfaat membantu': 'useful app helps',
#  'membantu seabank': 'help seabank',
#  'bagus mantap': 'good, great',
#  'kece no admin': 'Erase the ad people',
#  'siip': 'cool',
#  'mantappsangat membantu': 'great, very helpful',
#  'suka free transfer': 'like free transfers',
#  'gak lemot buka pokoknya oke gak rugi pake seabank': "It's not slow to open, just okay, there's no loss in using Seabank",
#  'transaksi cepat mudah': 'fast easy transaction',
#  'joss': 'joss',
#  'efektif': 'effective',
#  'bgus bnget seabank thanks seabank': 'really great seabank thanks seabank',
#  'mantap bebas biaya admin': 'great, no admin fees',
#  'senang make aplikasi': 'happy to use the application',
#  'tingkat lgi': 'another level',
#  'susah tarik tunai doang': "It's hard to withdraw cash",
#  'bagus banget': 'really good',
#  'gratis transfer mantap': 'Free transfers are great',
#  'trimakasih seabank mempermudah bertransaksi': 'Thank you Seabank for making transactions easier',
#  'puasssss': 'satisfiedsss',
#  'mantaaap betull sukaa bangett': 'great, really like it',
#  'bagis': 'BULLY',
#  'biar bintang yg berbicara': 'Let the stars do the talking',
#  'enak nyaman murah': 'delicious comfortable cheap',
#  'tolong lupa pasword sulit ganti pasword pengalaman buruk': 'please forget password difficult to change password bad experience',
#  'terbaik mudah transaksi senang karna free admin': 'Best, easy, happy transactions because admin is free',
#  'akun dibuka dibuka login simpanan uang': 'account opened opened login money savings',
#  'aplikasi buruk cicilan telat lunasi tarik tunai meminjam sengat kecewa aplikasi': 'Bad application, late installments, cash withdrawals, borrowing, stinging disappointment in the application',
#  'mengirim uang cepat ditambah bunganya pelayanan seabank pinjam semoga akun pelayanan trimakasih': 'send money fast plus interest Seabank loan service, thank you service account',
#  'aplikasinya bagus ringan dh kendala lanjaaayyy slaluuu transfer ewalet bank manapun gratis biaya admin suka buanget aplikasi membantu pertahankan n terima kasih': "the application is good, it's light and there are no problems, always transfer ewallet to any bank, free admin fees, I like it, the application helps, keep it up, thank you",
#  'kemarin transfer ovo gratis potongan mohon perbaiki': 'Yesterday, free OVO transfer was deducted, please fix it',
#  'manatap': 'temperature',
#  'aplikasi tolol c via telpon email ga respon ga dihubungi': 'stupid application c via telephone, email, no response, no contact',
#  'bagus banget aplikasinya mempermudah pembayaran shoppe': 'The application is really good and makes Shopee payments easier',
#  'burukkkkk poll gabisa transfer': "It's bad the poll can't transfer",
#  'super gratis': 'super free',
#  'membantu mempermudah urusan': 'help make things easier',
#  'top': 'top',
#  'seabank kerennnn': 'Seabank is cool',
#  'mudah d jga menyimpan tabungan good job': "It's also easy to save good job savings",
#  'mantul': 'helpful',
#  'sukses': 'success',
#  'lumayan bagus': 'pretty good',
#  'mudah mendaftarnya mudah menggunakannya': "it's easy to register, easy to use",
#  'tergolong super aplikasinya karna kepuasan bertransaksi perbankan transfer kesemua bank aktifitas transaksi bayar berbayar menarik bagus apps nya promo biaya admin bertransaksi transfer bank kali sbulan stiap transaksi nya lancar gak pending pending refund sy sngat mengapresiasi kinerja appsnya': 'It is classified as a super application because of the satisfaction of banking transactions, transfers to all banks, interesting payment transaction activities, good apps, promos, admin fees, bank transfer transactions once a month, every transaction is smooth, no pending refunds, I really appreciate the performance of the apps',
#  'memudahkan pembayaran': 'facilitate payment',
#  'aplikasinya smooth banget pake handphone jadul j pro oke': 'the application is really smooth using an old J Pro cellphone, okay',
#  'mudah pemakaiannya': 'easy to use',
#  'puji tuhan hematnya makasih': 'thank God for saving, thank you',
#  'good terbantu': 'good helped',
#  'cepat transper aja admin': 'Just transfer quickly admin',
#  'belanja aplikasi shope dll nyaman seabank': 'shopping app shope etc. convenient seabank',
#  'ok bgt': 'ok',
#  'karna': 'karna',
#  'seawal senang memudahkan semoga amanah seabank': 'as early as possible to facilitate the trust of seabank',
#  'senang seabanksangat muda': 'happy seabankvery young',
#  'cepet solutif': 'quick solution',
#  'membantu shebank': 'help shebank',
#  'mantap bagus': 'great, good',
#  'semoga lancar trsaksi trs': 'I hope the transaction continues smoothly',
#  'ribet': 'complicated',
#  'seabank is ok': 'seabank is ok',
#  'mantap gak ribetaman': 'great, no hassle',
#  'bayar shopee chackout memuat ulang trus beranda shopee tolong diperbaiki': 'pay shopee checkout keeps reloading shopee homepage please fix',
#  'mantullss free trf': 'mantullss free trf',
#  'pembayaran transfer mudah biaya admitcuma dsayangkan byr pbb area wilayah depok jakarta blm fitur pembayarannyahanya khusus wilayah ja jd blm komplititu ja si kekurangannya': "easy transfer payment, admit fee, just a pity by the PBB area, Depok Jakarta area, but the payment feature is only specific to the area, so it's not complete, that's the downside.",
#  'oke enak': 'okay delicious',
#  'kalo transfernya gratis ya bagus': "if the transfer is free that's good",
#  'm antap': 'm antap',
#  'suka seabank': 'love seabank',
#  'aksesnya cepat moga bertahan': 'access is fast, hope it lasts',
#  'baguss': 'nice',
#  'bagus suka': 'nice like it',
#  'c ramah membantu mengalami akun terblokir': 'c friendly to help those experiencing blocked accounts',
#  'okk': 'OK',
#  'siip bgt': 'very good',
#  'gak c nya penanganan kendalanya': "It's not c how to handle the problem",
#  'nyaman aja pakai seabank': 'just comfortable using seabank',
#  'mantab': 'great',
#  'bagus pake seabank suka seabank suxes': "it's good to use seabank, like seabank, it's successful",
#  'membantu memuaskan': 'help satisfy',
#  'aplikasi favoritq tf free x top up dana shopeepay free': 'favorite application tf free x top up free shopeepay funds',
#  'cekas': 'quick',
#  'kenapah login akun bank pasword nomor telepon pa login verifikasi ktp pa selesai login nik terdaftar binggung giliran login disuruh verifikasi ktp pa udah berhasil nik terdaftar gimana nh min': "why do you log in to your bank account, password, telephone number, login, ID card verification, complete login, nik is registered, confused, it's your turn to log in, you're told to verify your ID card, it's successful, nik is registered, how do you do that, min?",
#  'sngat membantu': 'very helpful',
#  'aplikasi terbaik': 'best application',
#  'terimakasih pelayanan nya': 'thank you for the service',
#  'recommended apk': 'recommended apk',
#  'transfer gratis terussss makasi seabankk': 'Continue free transfers using Seabank',
#  'terbantu': 'helped',
#  'mantap jiwa': 'steady soul',
#  'penglamn yg': 'experience',
#  'gg bagus': 'gg good',
#  'seabank bagus': 'seabank is good',
#  'mudah ga ribet': 'easy and not complicated',
#  'sea bank membantu mudah bertransaksi banyk fitur fiturnyasudah memakai seabank cuman sayang belom pinjamannya': "Seabank helps make transactions easy, lots of features, I already use Seabank, but it's a shame I don't have a loan yet",
#  'gak ribet': "it's not complicated",
#  'buatin fitur kantong mudah kayak aplikasi sejenis': 'make a simple pocket feature like a similar application',
#  'cepat': 'fast',
#  'aplikasi nya bagus ribet daftar nya': "The application is good, it's a hassle to register",
#  'bagus tingkatkan': 'good upgrade',
#  'good and simple': 'good and simple',
#  'mantapl pake seabank gratis': 'Great for using Seabank for free',
#  'bagus bermanfaat': 'good, useful',
#  'senang banget pake seabank': 'really happy to use seabank',
#  'anti ribet sat set membantu setor tunai tarik tunai mantap kali gaess semoga real bank fasilitas terintegrasi semoga prosedur gratis tranfer bank e wallet berubah i like sea bank thanks': 'anti-complicated sat set helps with cash deposits and cash withdrawals, guys, hopefully real bank has integrated facilities, hopefully the free e-wallet bank transfer procedure will change, i like sea bank, thanks',
#  'mantulll': 'mantulll',
#  'bagus semoga kedepan nya kartu debit nya': 'good, hopefully in the future there will be a debit card',
#  'bagus bangat layanan nya': 'the service is very good',
#  'aman mudah': 'easy safe',
#  'membantu skali': 'help skali',
#  'ga nyangka transaksi nya mudah suka seabank thanks sea bank': "I didn't expect the transaction to be easy, like Seabank, thanks Sea Bank",
#  'cepat no ongkir': 'fast no postage',
#  'praktis': 'practical',
#  'mantap abiz': 'great, Abiz',
#  'mantapok bangeeet': 'really cool',
#  'bank online terbaik': 'best online bank',
#  'keren bermanfaat': 'cool, useful',
#  'mudah praktis': 'easy and practical',
#  'gimana sih daftar akun seabank aja nunggu kode verifikasinya abad ga udah dicoba aja ga kekirim nomer aktifdan penyimpanan ga ngaruh hadehhh capee capeee': "How do you register a Seabank account? Just wait for the verification code, I haven't tried it yet, I haven't been sent an active number, and saving doesn't affect me, I'm tired, I'm tired, capeee",
#  'pakai aplksi slalu puas': 'using the application is always satisfied',
#  'the best': 'the best',
#  'nyoba mayan cepet bagus': 'Try to pay fast',
#  'transfer prose udah hub c ya gtu aja hati deh': 'Just contact C for the transfer process, just be careful',
#  'cepat mudah menggunakannya': 'quick and easy to use',
#  'jos': 'if',
#  'bermanfaat mempermudah transaksi bank': 'useful for making bank transactions easier',
#  'mntaop': 'mntaop',
#  'lumayan membantu': 'quite helpful',
#  'mantapzzz': 'cool',
#  'baguss mudah bertransaksi': 'nice, easy transaction',
#  'prose mudah cepatkirim biaya apapun mudah': 'easy process, fast sending at any cost is easy',
#  'belajar pengguna': 'learn users',
#  'mantap puas': 'really satisfied',
#  'transfer cepat gratis ribet trimakasih seabank maju pelayanan': "Fast, hassle-free transfers, thank you, Seabank's advanced service",
#  'kenyamanan nasabahnya terima kasih seabank': 'Customer convenience, thank you, Seabank',
#  'cocok transaksi': 'suitable transaction',
#  'mengubah nomor telepon': 'change phone number',
#  'mantap kalo bikin gratis ewalet': 'great time to make a free e wallet',
#  'membantu syang': 'help darling',
#  'nabung untung yaa seabank gak biaya transfer gak biaya bulanan dpt saldo trimakasih seabank': 'Profitable savings, Seabank, no transfer fees, no monthly fees, get a balance, thank you Seabank',
#  'terimakasih': 'Thank You',
#  'semoga kedepannya sukses membernya': 'I wish the members success in the future',
#  'mantap sukses seabank': "Seabank's continued success",
#  'good aplkasi': 'good aplkasi',
#  'fitur nya friendly fasilitas promo yg kasih nya memuaskan': 'The features are friendly, the promo facilities are satisfying',
#  'mudah gratis transfer ewalet': 'easy free e wallet transfers',
#  'overall lumayan memuaskan kinerja sea bank suka memakainya tingkat keamanan aplikasinya lumayan ketat jd gak ragu menyimpan dana simpanan transaksi bayar berbayar belanja sy mengapresiasi kenerja admin nya yng cepat tanggap keluhan keluhan aplnya lumayan enaklah pakai transaksitidak memakai ruang penyimpanan type ponsel mu rendah menggunakannya': "Overall, the performance of Sea Bank is quite satisfactory. I like using it. The security level of the application is quite tight, so I don't hesitate to save funds for payment transactions, pay for shopping, I appreciate the performance of the admin, who responds quickly to complaints, the application is quite easy to use, transactions don't use up storage space, your cellphone type is low on use.",
#  'cepet prosesnya': 'fast process',
#  'mantap permudah transaksi': 'Great for making transactions easy',
#  'apknya lumayanan bagus karna memudahkan utk transaksi saran klo pembayaran shoppe harap transfernya gratis': 'The apk is pretty good because it makes transactions easy. If you make a shop payment, please transfer it for free',
#  'baikk puas': 'ok satisfied',
#  'mudah n cepat': 'easy n fast',
#  'keamanan data terjaga terima kasih seabank': 'Data security is maintained, thank you Seabank',
#  'suka pake seabank tf super cepat': 'I like using Seabank TF super fast',
#  'cepat tujuan gratis lg biaya transfer ayo sea bank untung': 'Fast destination, free transfer fees, come on, Sea Bank makes a profit',
#  'sayang bank seabank dikenakan biaya gratiskan': 'Unfortunately Seabank is charged free of charge',
#  'appl membantu baget suka baget': 'appl helps baget like baget',
#  'ribet bjir sumpeh': "it's so complicated",
#  'bismillah': 'Bismillah',
#  'biaya transfer': 'transfer fees',
#  'memudahkan pmbayaran': 'facilitate payment',
#  'ok banget guysss': 'really okay guys',
#  'mudah membatu': 'easily petrified',
#  'download rekomendasi org transaksinya cepat aman fiturnya gak ribet': "Download people's recommendations, transactions are fast, safe, features are not complicated",
#  'murah feenya': 'cheap fees',
#  'tampa biaya admin': 'no admin fees',
#  'layanan nya memuaskan': 'the service is satisfying',
#  'aplikasi sagat bagus': 'very good application',
#  'bagus simpel': 'nice simple',
#  'apk busuk uang makan seabank uda kirim foto ktp asli rekening blokir': "Seabank's rotten food money apk has sent a photo of the original ID card of the blocked account",
#  'gratis transfer': 'free transfer',
#  'mudah penggunaannya': 'easy to use',
#  'sangan memudahkan transaksi': 'really makes transactions easy',
#  'pemula semoga kagak mengecewakan': "beginners, hopefully it won't disappoint",
#  'oke banget': 'really okay',
#  'bguusss': 'wow',
#  'gada fitur seabank pinjam tranksasi udah jutaan': "There's no Seabank feature, loan transactions are already millions",
#  'mudah praktis transfer bank kena biyaya': 'Easy, practical, bank transfers are subject to fees',
#  'sanga memuas kn': 'when satisfying kn',
#  'membantu berguna': 'useful help',
#  'seabank keren fleksibel': 'seabank cool flexible',
#  'memudahkan pergerakan': 'facilitate movement',
#  'limit saldo seabank': 'limit seabank balance',
#  'good job pokok nya': 'good job basically',
#  'mantap yg': "that's great",
#  'puas seabank': 'puas seabank',
#  'log out sih log in verifikasi muka ribet aja diulangulang': 'logging out, logging in, facial verification is just a hassle, repeating it over and over again',
#  'is the best': 'is the best',
#  'oke mantap': 'okay great',
#  'bagus bener': 'really good',
#  'seabank mantap': 'Seabank is great',
#  'biaya tf gratiscepatmudah': 'free fast easy tf fees',
#  'em iyagood jop aja': 'em without jop aja',
#  'alhamdulillah pakai seabank memudahkan semoga gk mengecewakan ya sukses seabank': "Thank God, using Seabank makes it easier, I hope you won't be disappointed, success with Seabank",
#  'sagat': 'hour',
#  'prose cepat mudah aman': 'fast easy safe process',
#  'terbaik pokok nya gak ribet': "The best thing is that it's not complicated",
#  'prose cepat': 'fast process',
#  'nyaman pake apk seabank transaksi aman biaya transaksi smoga kedepan nya': "It's comfortable to use the Seabank apk, safe transactions, hopefully transaction costs in the future",
#  'ok lancar': 'ok smooth',
#  'senang sea bank': 'happy sea bank',
#  'mantaaaaap': 'Mantaaa',
#  'bunga nya lumayan gede': 'the flowers are pretty big',
#  'web diam aja pa login': 'the website just stays silent when logging in',
#  'bagus apk nya sih bikin jdi agen tarik tunai transfer edc nya ka makasih': "It's good that the apk can be used as an EDC cash transfer agent, thanks",
#  'mantapppp': 'greatpppp',
#  'seabank membantu transaksi pembayaran apapun terimakasih seabank': 'seabank helps with any payment transactions, thank you seabank',
#  'bintangnya rubah pengalaman mengenakan berlibur daerah dimana sanggat sulit melalukan penarikan tunai jaringan indomaret beralasan mesin finggerprint penarikansekalinya bisasaya diwajibkan berbelanja penarikan dibatasi rp bekerjasama jaringan atm jangkauannya luas bank digital ayam hijau mudah penarikan': 'The star is changing the experience of using a vacation in areas where it is very difficult to make cash withdrawals. The Indomaret network is based on a fingerprint machine. Withdrawals are possible. Once you can, you are required to shop. Withdrawals are limited to IDR using the ATM network, which has a wide reach. The Green Chicken Digital Bank is easy to withdraw.',
#  'zulfahmi mantap cepat': 'Zulfahmi is great and fast',
#  'simpel mudah transfer bank': 'simple easy bank transfer',
#  'aplikasi bank digital terbaik': 'the best digital banking application',
#  'pelayanan cepat': 'fast service',
#  'knapa masuk tolong perbaiki lg': 'why come in please fix it again',
#  'pelayanan mantap': 'great service',
#  'lancar banget mengapresiasi kecepatan transaksi sea bank dgn nilai menurutku apps salah apps perbankan bagus pakai kendala sigap c sigap menyelesaiakan gangguan responsif sedetail detailnya suka tata letak menu menunya menurutku elegan mudah mengerti overall lumayan memuaskan detail transaksinya komplit kerenlah aplnya karna menabung dgn aman nyaman': 'very smooth, appreciate the speed of sea bank transactions with value, in my opinion the app is one of the good banking apps, use problems quickly, c quickly resolve problems, responsive in detail, like the layout of the menu, in my opinion, elegant, easy to understand, overall, quite satisfying, the transaction details are complete, the app is cool, because saving is safe, comfortable',
#  'puas pake seabank karna krm kmna geratis': "I'm satisfied with using Seabank because it's free to send anywhere",
#  'tambahin kartu debit fisik nya yng belogo visa kasih bintangnya': 'Add a physical debit card with the Visa logo and give it a star',
#  'penggunaanya mudah transfer menyenangkan biaya free bank': 'Easy to use, fun transfers, free bank fees',
#  'sidik jari ya konfirmasi transaksi baiklah pakai krom': 'fingerprint yes, confirm the transaction, fine, use chrome',
#  'kuota transfer beda bank ditambahi kak membantu': 'The additional transfer quota for different banks is helpful, bro',
#  'membantu darurat kendaraan': 'assist with emergency vehicles',
#  'ngga ribet gratis biaya tfr atm': 'No hassle, free ATM TFR fees',
#  'mantappppp transaksi lancar': 'great, smooth transaction',
#  'sea bank memudahkan nasabah dlm transaksi apapun kebutuhan keuangan': 'Seabank makes it easy for customers to carry out transactions for any financial need',
#  'praktis membantu': 'practically helpful',
#  'gratis mantap jaya sea bank': 'free, great, jaya sea bank',
#  'mengirim cepat': 'send fast',
#  'rockeeettt': 'rockeeettt',
#  'asik banget': 'really fun',
#  'virtual account shoppe ecommerce': 'virtual account shoppe ecommerce',
#  'semenjak pakee seabank ga ribettmudah transaksi': "Since using Seabank, it's not complicated, transactions are easy",
#  'mantap ngk nyesel pake': "It's good that I don't regret using it",
#  'instan cepat mantap potongan': 'instant, fast, steady cuts',
#  'gampang mudah': 'easy easy',
#  'prose nya cepat': 'the process is fast',
#  'bunga nya mantap': 'the flowers are great',
#  'amanah terpercaya': 'trusted trust',
#  'aq seneng bgt pake apk gara login bermasalah aq kasih bintang': "I'm really happy to use the apk because I'm having trouble logging in, I'm giving it a star",
#  'seabank pokok nya mantap dah': 'the main seabank is already stable',
#  'mantuk bgt': 'very sleepy',
#  'puas aplikasi': 'satisfied with the application',
#  'membantu bertransaksi': 'help with transactions',
#  'baguspraktis mudah': 'good practical easy',
#  'yg terbaik': 'the best',
#  'mantab penggunaan nya ribet': "Great, it's complicated to use",
#  'bagusss': 'nice',
#  'transaksi lengkap': 'complete transaction',
#  'yg komen org': 'who commented org',
#  'seabank yes': 'seabank yes',
#  'okee baguss fiturnya gratis biaya admin': 'OK, great feature, free admin fees',
#  'klu secepat nya tf menerima dana negri mudah aja si terima kasih': "If TF receives state funds as quickly as possible, it's easy, thank you",
#  '𝑴𝒆𝒎𝒂𝒏𝒈 𝒈𝒂𝒌 𝒂𝒅𝒂 𝒎𝒂𝒏𝒇𝒂𝒂𝒕 𝒔𝒆𝒂 𝒃𝒂𝒏𝒌 𝒏𝒊 𝒖𝒅𝒂𝒉 𝒃𝒓𝒂𝒑𝒂 𝒌𝒂𝒍𝒊 𝒌𝒖 𝒄𝒐𝒃𝒂 𝒑𝒂𝒔𝒔𝒘𝒐𝒓 𝒃𝒆𝒏𝒂𝒓 𝒅𝒊 𝒂𝒍𝒊𝒉𝒌𝒂𝒏 𝒌𝒆 𝒅𝒂𝒇𝒕𝒂𝒓 𝒃𝒂𝒓𝒖 𝒎𝒆𝒎𝒂𝒏𝒈 𝑨𝒑𝒍𝒊𝒌𝒂𝒔𝒊 𝒂𝒏𝒆𝒉 𝒕𝒐𝒍𝒐𝒏𝒈 𝒅𝒊 𝒑𝒆𝒓𝒎𝒖𝒅𝒂 𝒑𝒆𝒍𝒂𝒏𝒈𝒈𝒂𝒏 𝒖𝒏𝒕𝒖𝒌 𝒍𝒐𝒈𝒈𝒊𝒏 𝒏𝒊 𝒈𝒂𝒌': '𝑴𝒆𝒎𝒂𝒏𝒈 𝒈𝒂𝒌 𝒂𝒅𝒂 𝒎𝒂𝒏𝒇𝒂𝒂𝒕 𝒔𝒆𝒂 𝒃𝒂𝒏𝒌 𝒏𝒊 𝒖𝒅𝒂𝒉 𝒃𝒓𝒂𝒑𝒂 𝒌𝒂𝒍𝒊 𝒌𝒖 𝒄𝒐𝒃𝒂 𝒑𝒂𝒔𝒔𝒘𝒐𝒓 𝒃𝒆𝒏𝒂𝒓 𝒅𝒊 𝒂𝒍𝒊𝒉𝒌𝒂𝒏 𝒌𝒆 𝒅𝒂𝒇𝒕𝒂𝒓 𝒃𝒂𝒓𝒖 𝒎𝒆𝒎𝒂𝒏𝒈 𝑨𝒑𝒍𝒊𝒌𝒂𝒔𝒊 𝒂𝒏𝒆𝒉 𝒕𝒐𝒍𝒐𝒏𝒈 𝒅𝒊 𝒑𝒆𝒓𝒎𝒖𝒅𝒂 𝒑𝒆𝒍𝒂𝒏𝒈𝒈𝒂𝒏 𝒖𝒏𝒕𝒖𝒌 𝒍𝒐𝒈𝒈𝒊𝒏 𝒏𝒊 𝒈𝒂𝒌',
#  'suka gampang pakainya': 'I like it easy to use',
#  'senang seabank memudahkan transfer kemana semoga lancar seabank': "I'm glad Seabank makes it easy to transfer anywhere, I hope Seabank runs smoothly",
#  'membantu transaksi apapun': 'help with any transaction',
#  'bayar axis gabisamalah bilang cek keamanann gak sea bank gajelas': "Axis pay can't even say the security check is not as clear as bank",
#  'bgus': 'nice',
#  'seabank menerbitkan kartu debitnya': 'seabank issues its debit card',
#  'makasih membantu keuangan': 'Thank you for helping financially',
#  'perfect': 'perfect',
#  'mudah nyaman': 'easy comfortable',
#  'mudah dlm bertransaksi': 'easy to transact',
#  'okee': 'okay',
#  'cepat gratis': 'fast free',
#  'skrng sebank terbaik sllu tingkatkan pelayanan nya': 'Now the best Seabank always improves its service',
#  'anjay': 'Anjay',
#  'mantap apknya': 'the apk is good',
#  'app simple manapun': 'any simple app',
#  'penipi': 'fraudster',
#  'hmmm mudah pengoperasiannya tq': "hmmm it's easy to operate thq",
#  'tolongdong aktifasi seabank pinjam akun': 'Please activate your Seabank loan account',
#  'bagus aplikasi nya udh pakai ok ok bingung teman setahun s pinjam sendri knapa ya ga dapet transaksi udh puluhan juta mohon tinjau akun smoga bsa dapet s pinjam butuh': "the application is good, I've used it, ok, I'm confused, friend, I've been borrowing it for a year, why can't I get a transaction of tens of millions, please review the account, hopefully I can get it if I need a loan.",
#  'mantab seabank kecewa': 'Mantab Seabank disappointed',
#  'bunga tabungan nya bertambah sesuai akumulasi saldo tabungan': 'The savings interest increases according to the accumulated savings balance',
#  'bagus yaman aman': 'good, safe Yemen',
#  'kren': 'crane',
#  'daftar semoga berguna': 'hope the list is useful',
#  'mantap dpt bunga dr d bank konvensional yg kena potong': "It's great to get interest from conventional banks which are subject to cuts",
#  'membantu aktivitas': 'help with activities',
#  'membantu kebutuh': 'help the need',
#  'semoga bermanfaat membantu memudahkan menabung bertransaksi': 'Hopefully this is useful to help make saving transactions easier',
#  'semoga kendala': 'hopefully there will be problems',
#  'aplikasi membantu': 'helpful app',
#  'ewallet kalo gratis biaya transfer': 'ewallet if transfer fees are free',
#  'mohon ditingkatkan aplikasinya respinsif': 'please improve the responsiveness of the application',
#  'mudah dimana sajakapan gratis potongan biaya transfer bunganya jg lumayanseabank membantu gampang pembayaran yg pokoknya nggak nyesel aplikasi seabank': "it's easy anywhere, free discounts on transfer fees, the interest is also pretty good, seabank helps make payments easy and you don't regret the seabank application",
#  'makasih seabank': 'Thanks seabank',
#  'mantap cepat': 'steady fast',
#  'sangatt puasss': 'very satisfied',
#  'securitynya bagus mentedekti hp yg imei palsu': 'The security is good at detecting cellphones with fake IMEIs',
#  'keren bos ku': 'times forest ku',
#  'cepat akurat biaya admin': 'fast, accurate admin fees',
#  'yah instal seabank fitur seabank pinjam nya ga muncul teman': "Yes, install Seabank, the Seabank loan feature doesn't appear, friends",
#  'trx lancar': 'trx smooth',
#  'mantap jiwa semoga aman transaksi': 'Have a good soul, hope you have a safe transaction',
#  'aplikasi nya baguss': 'the application is good',
#  'mudah dipake': 'easy to use',
#  'terbaik sea bank': 'best sea bank',
#  'murah mudah': 'cheap easy',
#  'pa daftar pasword memenuhi syarat ya konfirmasi udah pake kombinasi hurufangka simbol karakter': 'If the password list meets the requirements, confirm that you have used a combination of letters, numbers, symbols, characters',
#  'seabank membantu': 'seabank helps',
#  'membantu prose cepat lbih sea bank mengadakan pinjaman modal usaha dll pengguna rekening sea bank jdi tdk susah susah cari modal usaha yg lainsemoga sea bank kedepan menampilkan performa terbaiknya aamiin': "helps the process more quickly, Sea Bank provides business capital loans, etc. for Sea Bank account users, so it won't be difficult to find other business capital. I hope Sea Bank will show its best performance in the future, aamiin",
#  'nyaman nabung': 'comfortable saving',
#  'kerja pinjol ilegal': 'illegal loan work',
#  'kelasssss': 'Kelassssss',
#  'seabank lemot aplikasinya jaringan telkomsel bagus': 'Seabank application is slow, Telkomsel network is good',
#  'bermanfaatkedepannya jam pagi ga gangguan': "useful in the future, the morning hours won't be a nuisance",
#  'transfer nya gratis keren': 'the transfer is free, cool',
#  'bagus nyaman nyimpan uang seabank aplikasi bank online': 'nice, comfortable saving money seabank online banking application',
#  'nyobain semoga mengecewakan': 'try it, hope it disappoints',
#  'ok tf gratis bank terpenting aman': 'ok free tf the most important bank is safe',
#  'cepat prosesnya': 'fast process',
#  'cepat transaksinya membantu bunganya': 'Fast transactions help with interest',
#  'mudah menyenangkan transfer transaksi dana cepat mudah': 'easy fun fast easy fund transaction transfer',
#  'layanan': 'service',
#  'mantap bagus puas': 'great, good, satisfied',
#  'terimakasih senang seabank': 'thank you happy seabank',
#  'lancar usaha lancar bisnis seabank mudah': 'smooth business smooth seabank business easy',
#  'biaya gratis': 'free of charge',
#  'tingkat ka n': 'level to n',
#  'senang sakli memakai app seabank bnar memudahkan': "I'm really happy to use the Seabank app, it's really easy",
#  'aplikasi udah bagus sih aplikasi aneh banget recommenin fingerprint login biar mudah menonaktifkan nya alasan keamanan kocak sumpah udah enak pake fingerprint ga': "The application is already good, the application is really strange, recommend fingerprint login so it's easy to deactivate it for security reasons, it's funny, I swear, is it really good to use fingerprints or not?",
#  'tingkatkan kualitas permudah acces prbanyak acces': 'improve quality, make access easier, increase access',
#  'cuman aja yg fitur² dialam ak gk dipakai kayak tf qris top up dll': "It's just that the features in AK are not used, like TF QRIS Top Up, etc",
#  'semoga saldo seabank': 'hopefully seabank balance',
#  'aplikasi keuangan yg bagusgratis transfer x': 'good financial application free transfer x',
#  'aplikasi bank ribet tolol password susah': 'The bank application is complicated, the password is difficult',
#  'mantap bos u': 'great boss u',
#  'enak': 'nice',
#  'aplikasi bagus fitur keren': 'nice app cool features',
#  'puas seabank bagus mudah d mengerti': 'satisfied, seabank is good, easy to understand',
#  'aplikasi': 'application',
#  'goodddddd': 'goodddddd',
#  'propesional praktisterpercaya': 'trusted professional practice',
#  'ok bsik': 'ok bsik',
#  'overall nyaman detail transaksinya membuatku bertahan aplikasi salah keunggulan apl gak biaya admin melakuakan transaksi transfer bank bank berlaku kali transaksi dlm bulannya cocok keperluan bisnis pribadi tingkat keamanannya gak diragukan dana tersimpan sebagi modal aman tdk ragukan': 'overall comfortable, the transaction details made me survive the wrong application, the advantage of the application is that there are no admin fees, carrying out bank transfer transactions, the bank is valid every month, according to personal business needs, the level of security is not in doubt, the funds are stored as safe capital, there is no doubt',
#  'kalo transfer bank bebas biaya admin batasi': 'If bank transfers are free, admin limits fees',
#  'simple banget bnyk pilihan ny': 'Very simple, lots of choices',
#  'mantap seabank pokonya the be': 'steady seabank anyway the be',
#  'bertransaksi aman efektif': 'safe and effective transactions',
#  'mantap transfer bank gratis': 'great free bank transfer',
#  'semoga membantu': 'I hope this helps',
#  'hati² kalo menaruh uang ya sy kmrn seabank gagal masuk ber ulang² pdhl alamat tolong perbaiki': 'be careful when you put money in, then seabank failed to log in repeatedly even though the address please correct it',
#  'baguss membantu bertransaksi': 'Nice help with transactions',
#  'senang hati': 'happy',
#  'tampilannya keren simpel cepat aplikasi nya digital banking cocok banget gaya hidup anak mudah': "it looks cool, simple, fast, the digital banking application really suits a child's easy lifestyle",
#  'semoga sukses abadi': 'good luck eternal success',
#  'bagus mudah penggunaan nya': 'good, easy to use',
#  'transaksi mudah': 'easy transaction',
#  'membantu era digital skarang piturnya bagus mudah mengerti': "helps in today's digital era, the features are good, easy to understand",
#  'apalah make apknya aja disuruh hubungi customer service tulisan layanan tersedia hubungi customer service udah abis pulsa k tetep gabisa apk': "Did you just use the account and was told to contact customer service, it said service is available, contact customer service, I've run out of credit, but I still can't get the APK.",
#  'tolong akun seabank buka kali coba masuk gagal': 'please open seabank account, login attempt failed',
#  'biaya pulsa paketnya mahal': 'The package credit fee is expensive',
#  'terbaik membantu': 'best help',
#  'enak pake seabank gratis kirim kemana aj pedagangkalo setor duit tfjadi pake seabank enak lahmantap jiwa pkok ya': "It's nice to use Seabank, it's free to send wherever the trader wants, if you deposit money then use Seabank, it's delicious, it's really good for your soul, right?",
#  'kelaz': 'come on',
#  'mudah cepat bget': 'very easy and fast',
#  'yapppss': 'yapppss',
#  'gampang mudah daftarnya': "it's easy to register",
#  'alhamdulillah seabank mempermudah transaksi': 'Thank God Seabank makes transactions easier',
#  'bagusdan cepat aman': 'good and fast safe',
#  'prose cpt': 'prose cpt',
#  'pokoke ter': "it's okay",
#  'scam': 'scam',
#  'mantab aplikasi membantu': 'great helpful application',
#  'tergolong lancar banget sea bank sy mengapresiasi kecepatan transfernya bank dgn nilia menarutku aplikasi salah aplikasi perbankan bagus pakai keperluan pribadi bisnis bayar bayar transaksi transferan nya gratis x biaya admin kesemua pengguna bank syarat menurutku salah kelebihan tersendiri bank digital menarik pengguna tuk melirik aplikasi pakai kawan ya': 'Sea Bank is classified as very smooth, I appreciate the transfer speed of Nilia Bank, I think the application is a good banking application for personal use, business, pay, transfer transactions are free, x admin fees for all bank users, according to me, one of the special advantages of digital banking is that it attracts users to look at the application using friends, OK?',
#  'mantep': 'steady',
#  'apk nya bagus terjamin keamanannya': 'The apk is good, guaranteed security',
#  'bagus aplikasinya': 'good application',
#  'pisau belati meja awas jatuh terkena mata hati beli kawasaki ninja daya sakukurata': 'Beware of table daggers falling into your eyes. Buy a Kawasaki Ninja Sakura Power',
#  'bank terbaik': 'best bank',
#  'terima kasih y dh harapan palsu ny': 'Thank you for your false hopes',
#  'aman terpercaya': 'safe, reliable',
#  'biaya transfer gratis aplikasinya simpel mudah': 'free transfer fees, the application is simple and easy',
#  'memuaskanapapun tanyain dm akun ignya cepet bgt responnya terimkasih seabank': "If you're satisfied, ask me on your IG account, the response is really fast, thank you, Seabank",
#  'adain paylater donk': 'Have a paylater please?',
#  'bermanfaat pisan': 'very useful',
#  'ok pakai lncar': 'OK, use it smoothly',
#  'memuaskan pakai berkembang aman seabank': 'Satisfied use safe growing seabank',
#  'aplikasi simpel transfer menyimpan uang menyenangkan karna bertambah harinya': 'Simple transfer application to save money is fun as the days increase',
#  'menunggu apkah apl seabang meminjami dana': 'Waiting to see if Seabank APK lends funds',
#  'membantu ya kawan kawan aplikasi mantul': 'help me, my friend, the application bounces',
#  'sy br mnggunakan seabank alhamdulillah puas dpt gratis admin': 'Sybr uses Seabank, thank God, fasting gets free admin',
#  'keren mantap mudah banget seabank': 'cool, really easy, seabank',
#  'ok bagus': 'OK, great',
#  'keren sih semoga atm indonesia kartu nya': "It's cool, I hope the Indonesian ATM has a card",
#  'trf bank gratis': 'trf bank for free',
#  'seabank puas': 'seabank puas',
#  'bagus admin': 'good admin',
#  'puas sma aplikasi seabank trima ksih udh bikin snang amn nyaman': 'Satisfied with the Seabank application, thank you for making me happy and comfortable',
#  'aplikasi digital banking yg cocok tranksasi tampilan simpel mudah': 'digital banking application that is suitable for easy, simple display transactions',
#  'transaksi fast respon': 'fast response transaction',
#  'seabank sandi wajah gak hack memuaskan': 'seabank face password does not hack satisfactorily',
#  'buka rekening seabank bonus mind': 'open a seabank bonus mind account',
#  'login nomor aktif otp coba live chat disuruh login kocak': 'login active number otp try live chat being told to log in is hilarious',
#  'transaksi udah xjam prose udh melebihi bata estimasi ditambah xjam gimana ni seabank tolong nipu gini': 'The processing time for the transaction has exceeded the estimated limit, plus what time is Seabank, please cheat like this',
#  'puas fiturnya gk atmnya tp saran kedepannya terbitkan atmnya': "I'm not satisfied with the features of the ATM, but my suggestion is to publish an ATM in the future",
#  'aplikasi nya bagus banget memudahkan pembayaranpokok nya the best lahh': 'the application is really good, it makes payments easy, the main thing is the best',
# ...
#  'cepat akurat': 'fast accurate',
#  'ok om': 'ok if',
#  'aplikasi bagus mudah diakses recomen orang': 'good application, easy to access, people recommend it',
#  'puas skali': 'satisfied',
#  'okk pokok nya': "ok that's the point",
#  'gut': 'gut',
#  'semoga lancar kendala': 'I hope the problem goes smoothly',
#  'teman login aplikasi tdk suruh nelpon costumer service eror egk masuk uang nya pakek bayar kuliah sungguh mengecewakan': "Friends, if you logged in to the application, you didn't ask to call customer service, the error didn't come in. The money used to pay for college was really disappointing",
#  'cepet gratis nya': "it's free fast",
#  'aman sbagai pengguna seabank prose transfer cepat akurat': 'safe as a Seabank user, fast, accurate transfer process',
#  'thebest': 'thebest',
#  'pelayanan': 'service',
#  'bank yg bagus membantu tolong kalo transfer bank yg biaya admin kasih bintang yaa': 'good bank helps, please give a star if you have a bank transfer with admin fees',
#  'tlong gratis admin bank': 'free bank admin please',
#  'suka pake nya tf gratissss k bank terimakasih': 'I like using TF for free at the bank, thank you',
#  'alhamdulillah kendala apapun lancar sea bank': 'Thank God, whatever obstacles there were, Sea Bank went smoothly',
#  'mudah pengunaan terimakasih sea bank': 'easy to use thank you seabank',
#  'udah make nya alhamdulillah aman': "I've used it, thank God it's safe",
#  'gratis biaya transfer': 'free transfer fees',
#  'aplikasi ny bagusmudah': 'easy good app',
#  'mmbatu': 'people',
#  'fast respon dah': 'fast response already',
#  'simpel praktis': 'simple practical',
#  'biaya transfer gratis transaksi': 'free transaction transfer fees',
#  'bagus mengecewakan sesuai simple tingkatkan pelayananya': 'good, disappointing, simple to improve service',
#  'fitur pinjam d aplikasi ya': 'borrow feature in the application',
#  'potongan pa dana masuk mahal': 'Deductions for incoming funds are expensive',
#  'aplikasi bagus transaksinya mudah': 'good application, easy transactions',
#  'kecewa promo iklannyakatanya saldo gratis rp nggak adatapi transaksi bagus gratis biaya transfer': 'Disappointed in the advertising promo saying there is no free IDR balance but the transaction is good, free transfer fees',
#  'bagus invest': 'good investment',
#  'sesuai informasinya': 'according to the information',
#  'mantep cepat': 'steady fast',
#  'aplikasi goblokkk ngirim kode verifikasi sm ngapain cokk udh wa sm nomor yg dikirim sm hpnya mati': 'The stupid application sends a verification code and why is there a WA and the number sent when the cellphone is dead',
#  'seabank membantu mudah pakainya': 'seabank makes it easy to use',
#  'seabank mudah cepat transfernya': 'Seabank transfers are easy and fast',
#  'naikin donk limit pinjaman nya': 'Please increase the loan limit',
#  'suka aplikasi inipelayanan nya memuaskan fitur chat telepon': 'I like this application, the service is satisfying, the telephone chat feature',
#  'aplikasi seabank ngga pencet top upp ewallet ga transfer ga butuh uang': "Seabank application doesn't press top up ewallet, doesn't transfer, doesn't need money",
#  'jd mudahbanyak gratis kirim nya': "So it's easy, lots of free shipping",
#  'simpel cepat': 'simple fast',
#  'senang x': 'happy x',
#  'pokoknya mantap': 'basically great',
#  'seabank terbaik': 'best seabank',
#  'good luck': 'good luck',
#  'mantap apk nyagratis transfer': 'great apk with free transfer',
#  'cepat gratis mantap': 'fast, free, great',
#  'semoga percobaan yg kali in si pinjam nya terpakai': 'Hopefully the experiment he borrowed this time will be used',
#  'sukses slalu': 'always successful',
#  'gampang': 'easy',
#  'pemgiriman cepat kenda menyukai nya': 'Fast delivery, you like it',
#  'overall bagus': 'overall good',
#  'seabank gampang kl utk transfer beda bankcepat gampang': 'Seabank is easy to transfer to different banks quickly and easily',
#  'cepat praktis terimakasih': 'fast and practical, thank you',
#  'bagus sukses trus': 'good luck then',
#  'aplikasi mudah': 'easy application',
#  'semoga kejutan': 'hopefully a surprise',
#  'kerennnn seabank': 'cool seabank',
#  'nikmat aplikasix bos': 'Nice application, boss',
#  'gabisa transfer': "can't transfer",
#  'bagus mudah': 'good easy',
#  'transfergratis bankbunga tinggidan terpercayamantap': 'Free high interest and reliable bank transfers',
#  'kerennn simple transaksi': 'cool, simple transaction',
#  'atm aman besama': 'ATM will be together',
#  'mempermudah urusan transfer bankmaupun qris': 'simplify bank and qris transfers',
#  'semoga sukses sea bank ku': 'Good luck with my sea bank',
#  'full': 'full',
#  'puascepat aman': 'be satisfied quickly and safely',
#  'fitur free top up ewallet nya ewallet kalo': "ewallet's free top up feature is ewallet if",
#  'sanggat': 'damn',
#  'seabank memudahkan bertransaksi aman lancar prose cepat': 'Seabank makes it easy to make safe, smooth transactions with a fast process',
#  'top banget simple banget': 'very top, very simple',
#  'aplikasi rekomendasi': 'Recommendation application',
#  'ajah ya': 'never mind',
#  'membantu pedagang': 'help traders',
#  'cepat bermanfaat': 'quickly useful',
#  'prose mudah cepat masuk nya': 'the process is easy and quick to enter',
#  'cepat top up tranfer': 'fast top up transfer',
#  'mudah ribet transaksi': 'easy and complicated transactions',
#  'semoga paylater': 'hopefully paylater',
#  'akses cepat': 'fast access',
#  'senang bertransaksi seabank transfer gratis bank': 'happy to transact seabank free bank transfer',
#  'aplikasinya bagus bunga': 'nice application flower',
#  'aplikasi ringan transfer gratis pertahankan': 'light application free transfer keep it up',
#  'pembayaran murah sip pokoknya': 'Cheap payments, basically',
#  'aplikasi menampilkan saldo': 'the application displays the balance',
#  'memudahkan transaksi adm nya': 'makes admin transactions easier',
#  'membantu semoga lancar': 'help hope it goes smoothly',
#  'mudah pakainya': 'easy to use',
#  'benci invalid qris': 'hate invalid qris',
#  'mantull': 'coat',
#  'membantu mudah': 'easy help',
#  'mantaap': 'temperature',
#  'membatu kebutuhan transaksi sehari terimakasihseabank': 'Helping with daily transaction needs, thank you Seabank',
#  'mantap gak kalah ewallet mantap': 'great, no less than a great ewallet',
#  'seabank memeng terbaik semoga membantu': 'Seabank is the best, hope this helps',
#  'mantaf': 'mantaf',
#  'baguss bgtt cepat transaksi nya': 'Very good, fast transaction',
#  'aplikasi mudah bebas transfer bank': 'easy application free of bank transfers',
#  'rekomendasi': 'recommendation',
#  'lalod bole permudah akses': 'Lalod can make access easier',
#  'smua gampang mudah seabnk sllu membantu terimkasih seabank': 'everything is easy, seabank always helps, thank you seabank',
#  'suka praktis gratiiiis': "like it's practically free",
#  'alhamdulillah menguntungkan seabank tf operator top up e wallet gratis saran seabank buka bank fisik pengen deposit tp kalo ga bank fisik nya kota berani kalo ketemu langsung yg ngurusi': "Thank God, it's profitable for Seabank TF, free e-wallet top up operator, seabank advice, open a physical bank, want to make a deposit, but if you don't have a physical bank, the city is brave if you meet the person who takes care of it in person.",
#  'menabung aman terpercaya': 'safe, reliable savings',
#  'apk bodoh': 'stupid apk',
#  'happy': 'happy',
#  'bgos': 'bgos',
#  'kasih bagus': 'nice love',
#  'bank bagus sayaaa semoga kedepannya adain kartu fisik yaaa': 'I hope my bank will have physical cards in the future',
#  'sangan bermanpaat': 'very useful',
#  'bagus bgt': 'really good',
#  'amanah aplikasi nya': 'Trust the application',
#  'pake seabank transaksi pake verivikasi wajah ribet verifikasi sidik jari ga karna loading kouta': 'Using Seabank, transactions using face verification are complicated, fingerprint verification or not because of loading quota',
#  'good bank': 'good bank',
#  'ya senang': 'yeah happy',
#  'gak klik akun udah masuk gak': "If you don't click, are you logged in or not?",
#  'enak gratis transfer kemana aja sampk kali': "It's nice to have free transfers anywhere and anytime",
#  'hah': 'hah',
#  'tf seabank simple gratis admin': 'tf seabank simple free admin',
#  'baguss sekalii': 'very good',
#  'uang hadiah': 'prize money',
#  'membantu bermanfaat': 'helpful useful',
#  'c profesional gak telpon c solusi no hp hilang masukin kode o tp nya': "c professional doesn't call c solution lost cellphone number enter code o tp",
#  'performa': 'performa',
#  'sea banksaya banget kendala trasfer saldo belom terimahati pengguna sea bankmending pakai bank aja': "Seabank, I really have problems transferring balances, it hasn't received any support from Sea Bank users, it's better to just use the bank",
#  'seabank top': 'seabank top',
#  'mudah cepat gratis hehehehe': 'easy fast free hehehehe',
#  'done': 'done',
#  'pengiriman cepan gratis admin': 'admin free fast delivery',
#  'membantu prose transaksi uang': 'help with the money transaction process',
#  'pemakaian cepat': 'fast use',
#  'mempermudah bertransaksi': 'make transactions easier',
#  'aplikasi memudahkan bertransaksi': 'the application makes transactions easy',
#  'no drama bagus aplikasinya': 'no drama, good application',
#  'aplikasinya sgt membantu dlm khdpn sehari tingkatkan lg performa': 'The application is very helpful in everyday life and improves performance',
#  'mudah untungnya belanja diskon': "it's easy and profitable to shop at discounts",
#  'pokonya biasaa mantappp jiwaaaa': 'Basically, the spirit is usually stable',
#  'bermanfaat menabung transfer bank': 'useful for saving bank transfers',
#  'praktis aman ngga ribet': 'practically safe and not complicated',
#  'mantap free admin bebas transfer daftar rekening mudah yg gua cari thx seabank': "great, free admin, free transfer, easy account list that I'm looking for, thx seabank",
#  'suka banget tf biaya admin': 'really like tf admin fees',
#  'bermanfaat prose cepat yg terpercaya pengiriman uang bank terima kasih seebank': 'useful, reliable fast process for bank money transfers, thank you seebank',
#  'coba ji': 'try it',
#  'mudah cepat aman': 'easy, fast, safe',
#  'lopyu all': 'lopyu all',
#  'permudah': 'make it easy',
#  'apk yg bagus': 'good apk',
#  'gratis tf x': 'free tf x',
#  'mudah aman dna ga ribet': 'easy, safe and not complicated',
#  'kasih bintang ya klau lancar bagus bintang': "Give it a star, if it goes well, it's a star",
#  'menyukai seabank aplikasi seabank membantu dlm pembayaran': 'like seabank the seabank app helps with payments',
#  'nyoba nya geratisan transaksi apl lumayang kalo transaksi berbisnis': 'Try it, the free app transactions are good for business transactions',
#  'seabank terbaik gratis transfer gratis top up sepuasnya': 'best seabank free transfers free top ups as much as you like',
#  'beneran cash back rb': 'really cash back IDR',
#  'sumpah seneng bgt pake sebnk tf gratis bank bungga nabung seabank aman terpercaya suka bgt harap ngak berubah sgt membantu suka bgt': "I swear I'm really happy using Seabank TF, free interest bank, Seabank savings, safe, reliable, I really like it, hope it doesn't change, it really helps, I really like it",
#  'bagus transaksi sayangnya seabank pinjam fiturnya': 'good transaction, unfortunately seabank borrowed the feature',
#  'seabank gak bsa tranfer': "Seabank can't transfer",
#  'aplikasi sampah gak disaat dana raib puluhan juta disana tertera nomor penerima gak transfer pa ku cek nomor rekening penerima rekening judi seabank shopee mendukung penuh perjudian': "Isn't this a rubbish application when tens of millions of funds are lost? It says the recipient's number doesn't transfer, I check the account number of the recipient of the Seabank gambling account. Shopee fully supports gambling.",
#  'nyoba': 'try',
#  'sesimpel kah transaksi seabank': "It's as simple as a Seabank transaction",
#  'memuaskan sukses tingkatkan kepuasan yaa': 'satisfy success increase satisfaction',
#  'free pokonya seneng': 'free anyway happy',
#  'amazing mantap': 'amazing great',
#  'transaksi lancar mudah': 'easy smooth transaction',
#  'mantap ok': 'great okay',
#  'sip mntap': 'sip mntap',
#  'the best si kirim gratis jarang gangguan misala da gangguan langsung cepet penangannya': 'The best is sent free, there are rarely any problems, for example if there is a problem, it is handled quickly',
#  'semoga pelayanan terbaik terima kasih seabank': 'I hope you have the best service, thank you Seabank',
#  'membantu trimakasih sebank': 'help thank you seabank',
#  'trimakasih prose cepat mudah': 'Thank you, fast and easy process',
#  'nyimpen uang transaksi shopee aman mudah penggunaannya': 'save money from shopee transactions safely, easy to use',
#  'senang mengunakan seabank krna biaya admin yg murah tampilan aplikasi nya keren': 'happy to use seabank with cheap admin fees, the appearance of the application is cool',
#  'direkomendasi aplikasi inisangat jelek bermanfaat': 'This application recommendation is very useful',
#  'aplikasi gaje': 'Gaje application',
#  'bagus banget suka': 'really good like it',
#  'pakai seabank transfer handphone kesemua bank': 'Use Seabank mobile transfer to all banks',
#  'aplikasi buruk daftar susah': 'bad application hard list',
#  'membantumudahdan nyaman': 'help easy and convenient',
#  'wow bangettt': 'wow really',
#  'sesuai ekpektasi': 'according to expectations',
#  'lancar mudah simple': 'smooth easy simple',
#  'mantul serba berguna': 'very useful',
#  'mencoba terbaru': 'try the latest',
#  'alangkah baiknya memudahkan isi pulsa kuota': 'It would be nice to make it easier to top up your quota credit',
#  'memuaskan apk': 'satisfying apk',
#  'praktis pembayaran onlen': 'practical online payments',
#  'seabak sngat mudah bermanfaat bnyak gratisannya': 'Seabank is very easy, useful, lots of freebies',
#  'mantap super tambhkan fitur card nya': 'Super cool adding the card feature',
#  'kalinya pakai aplikasi': 'First time using the app',
#  'hati hati aja seabank login persulit': 'Just be careful, Seabank login is difficult',
#  'aplikasi yg membantu gratis transfer terimakasih seabank': 'Helpful application, free transfers, thank you Seabank',
#  'tlong bantu lupa password': 'please help forgot password',
#  'bagus senang membantu bergabung seabank semoga amanah': 'good, happy to help join seabank, hopefully trustworthy',
#  'aman nyaman semoga amanah': 'safe, comfortable, hopefully trustworthy',
#  'tf k bank gratis': 'TF to bank is free',
#  'bank digital lengkap mudah fiturnyagratis transfer kesemua bankmemberikan keuntungan': 'Complete digital bank, easy features, free transfers to all banks provide benefits',
#  'bank murah aman': 'cheap safe bank',
#  'aplikasinya oke bgt dapet bunga jg nabung dikit pake kode referal vkkexe gaiss pa bikin akun biar dapet saldo k': 'the application is ok, you can get interest and save a little by using the vkkexe referral code, guys, can you create an account so that you can get the balance?',
#  'beruntung': 'lucky',
#  'membantu limite gratis transaksi berkali': 'Helps with free multiple transaction limits',
#  'membantu dibutuhkan': 'help needed',
#  'yes yes yes': 'yes yes yes',
#  'bikin mudah': 'make it easy',
#  'aplikasi sgt bagus': 'very good application',
#  'kecewa berat saudara transfer beli obat ayah obat tebus riwayat transaksi uang masuk saldo alasan akun rekening amankan ei prose jawabannya nunggu hati kerja butuh uang banget nyawa meninggal kembalikan uang nya cepat': "very disappointed, brother, transfer to buy medicine, father's medicine, redemption of transaction history, money entered balance, reason account account, secure ei process, answer, wait, work, heart really needs money, life dies, return the money quickly",
#  'prosesnya cepat mudah': 'the process is fast and easy',
#  'alhamdulillah senang': "thank God I'm happy",
#  'mudah ribet sukses seabank': 'easy and complicated, seabank success',
#  'senang bisah login alhamdulillah': "I'm glad I was able to log in, thank God",
#  'iklannya buka rekening dpt rbu boro dpt rbu bintang aja': 'The advert says that if you open an account you can get thousands of stars and get thousands of stars',
#  ...}

# %%
data.replace(translations, inplace = True)
data
# Out:
#                                    content_normalisasi2
# 0                                                  Good
# 1                                                 solid
# 2                                    no minimum balance
# 3                                                 limit
# 4                                                urgent
# ...                                                 ...
# 3439                                  Thank you Seabank
# 3440  Satisfying free transfers make it easier for u...
# 3441                                   simple easy fast
# 3442  Enter my account, the balance is sufficient, I...
# 3443                                 very quick to help
#
# [3444 rows x 1 columns]

# %%
data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTranslated.xlsx', index=False)

# %%
#SPLIT DATA
import pandas as pd

dataset = pd.read_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTranslated.xlsx')

# Hitung jumlah baris dalam dataset
num_rows = len(dataset)

# Hitung jumlah baris yang akan digunakan sebagai pelatihan (disini 50%)
train_size = int(0.5 * num_rows)

# Bagi dataset menjadi subset pelatihan dan pengujian
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Simpan subset pelatihan ke dalam file xlsx
train_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTrainEnglish.xlsx', index=False)

# Simpan subset pengujian ke dalam file xlsx
test_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/GetContact_DataTestEnglish.xlsx', index=False)

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from Textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (4.67.1)

# %%
from textblob import TextBlob

# %%
train_data
# Out:
#                                    content_normalisasi2
# 0                                                  Good
# 1                                                 solid
# 2                                    no minimum balance
# 3                                                 limit
# 4                                                urgent
# ...                                                 ...
# 1717                                nice to get flowers
# 1718  hopefully developing the application will be s...
# 1719                         sure to make things easier
# 1720                                                yup
# 1721               fast free delivery, really delicious
#
# [1722 rows x 1 columns]

# %%
data_content = list(train_data['content_normalisasi2'])
polaritas = 0

status = []
total_positif = total_negatif = total = 0

for i, tweet in enumerate(data_content):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')
    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 1106
# Negatif = 616
#
# Total Data : 1722

# %%
status = pd.DataFrame({'Label': status})
train_data['Label'] = status
train_data
# Out:
# <ipython-input-45-ddb1f5b9bf00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Label'] = status
#                                    content_normalisasi2    Label
# 0                                                  Good  Positif
# 1                                                 solid  Negatif
# 2                                    no minimum balance  Negatif
# 3                                                 limit  Negatif
# 4                                                urgent  Negatif
# ...                                                 ...      ...
# 1717                                nice to get flowers  Positif
# 1718  hopefully developing the application will be s...  Positif
# 1719                         sure to make things easier  Positif
# 1720                                                yup  Negatif
# 1721               fast free delivery, really delicious  Positif
#
# [1722 rows x 2 columns]

# %%
# Memisahkan data berdasarkan label
positif_data = train_data[train_data['Label'] == 'Positif']
negatif_data = train_data[train_data['Label'] == 'Negatif']

# %%
# Menentukan jumlah sampel minimum di 2 kelas kelas
min_samples = min(total_positif, total_negatif)

# %%
from sklearn.utils import resample

# %%
# Melakukan penyeimbangan data dengan undersampling
positif_data_resampled = resample(positif_data, replace=False, n_samples=min_samples, random_state=42)
negatif_data_resampled = resample(negatif_data, replace=False, n_samples=min_samples, random_state=42)

# %%
# Menggabungkan kembali data yang telah disusun ulang
balanced_data = pd.concat([positif_data_resampled, negatif_data_resampled])

# %%
data_content_balanced = list(balanced_data['content_normalisasi2'])
polaritas_balanced = 0

status_balanced = []
total_positif_balanced = total_negatif_balanced = total_balanced = 0

for i, tweet in enumerate(data_content_balanced):
    analysis = TextBlob(tweet)
    polaritas_balanced += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif_balanced += 1
        status_balanced.append('Positif')
    else:
        total_negatif_balanced += 1
        status_balanced.append('Negatif')

    total_balanced += 1

print(f'Hasil Analisis Data Setelah Penyeimbangan:\nPositif = {total_positif_balanced}\nNegatif = {total_negatif_balanced}')
print(f'\nTotal Data Setelah Penyeimbangan: {total_balanced}')
# Out:
# Hasil Analisis Data Setelah Penyeimbangan:
# Positif = 616
# Negatif = 616
#
# Total Data Setelah Penyeimbangan: 1232

# %%
train_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTrainEngLabeled.xlsx',index=False)

# %%
balanced_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTrainEngLabeledBalanced.xlsx', index=False)

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTrainEngLabeledBalanced.xlsx'
output_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTrainIdnLabeledBalanced.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content_normalisasi2'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
# Out:
# Translation complete. Translated data saved to a new Excel file!

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/GetContact_DataTestEnglish.xlsx'
output_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Seabank_DataTestIndo.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content_normalisasi2'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
# Out:
# Translation complete. Translated data saved to a new Excel file!
