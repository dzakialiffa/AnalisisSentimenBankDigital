# %%
#mounting google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# Memuat data dari file
df = pd.read_csv('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/BluBCA.csv')

# %%
# Eksplorasi data
df.head() # Menampilkan beberapa baris pertama data
# Out:
#                                reviewId              userName  \
# 0  f5830de6-6256-449c-9e29-d65f275f3d41                El Kun
# 1  45268cb7-355d-4573-9b8a-1cf5a1ea23d5  Muhamad Ajwad Mirwad
# 2  25079e2e-43bd-453f-bfff-93f1f4374b1e     alin cantik Kudus
# 3  e0ecfaa2-7360-4c62-bdaa-1987d7e47d14       Muhamad Aditiya
# 4  a27f03ba-4889-4461-a090-a1f53cac85b4          rudi santoso
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                                             ok lah      5              0
# 1                                       mantap pisan      5              0
# 2                                   sangat memuaskan      5              0
# 3  Transfer BCA ke Blu pake biaya admin, jd males...      1              0
# 4                        Mudah prosesnya tpi gak acc      4              0
#
#   reviewCreatedVersion                   at  \
# 0              1.59.20  2025-01-20 08:56:57
# 1              1.59.20  2025-01-20 07:04:34
# 2                  NaN  2025-01-20 04:34:40
# 3              1.59.20  2025-01-20 03:07:15
# 4              1.59.20  2025-01-20 02:22:32
#
#                                         replyContent            repliedAt  \
# 0  Hai, Kak El Kun. Terima kasih atas ulasannya. ...  2025-01-20 09:09:01
# 1  Hai, Kak Muhamad. Terima kasih atas ulasannya....  2025-01-20 07:19:26
# 2  Hai, Kak Alin. Terima kasih atas ulasannya. Se...  2025-01-20 04:46:32
# 3  Hai, Kak Muhamad. Maaf atas ketidaknyamanannya...  2025-01-20 03:33:46
# 4  Hai, Kak Rudi Santoso. Terima kasih atas ulasa...  2025-01-20 02:36:21
#
#   appVersion
# 0    1.59.20
# 1    1.59.20
# 2        NaN
# 3    1.59.20
# 4    1.59.20

# %%
# Membaca dataset CSV

# Mengecek baris yang mengandung link di kolom 'content'
rows_with_links = df[df['content'].str.contains(r'http\S+|www.\S+', na=False)]

# Mengecek baris yang mengandung simbol di kolom 'content'
rows_with_symbols = df[df['content'].str.contains(r'[^\w\s]', na=False)]

# Mengecek baris yang mengandung whitespaces di kolom 'content'
rows_with_whitespaces = df[df['content'].str.contains(r'\s+', na=False)]

# Mengecek baris yang mengandung angka di kolom 'content'
rows_with_numbers = df[df['content'].str.contains(r'\d+', na=False)]

# Menampilkan hasil
print("Baris yang mengandung link di kolom 'konten_ulasan':")
print(rows_with_links[['content']])
print(f"Jumlah baris yang mengandung link: {len(rows_with_links)}\n")

print("Baris yang mengandung simbol di kolom 'content':")
print(rows_with_symbols[['content']])
print(f"Jumlah baris yang mengandung simbol: {len(rows_with_symbols)}\n")

print("Baris yang mengandung whitespaces di kolom 'content':")
print(rows_with_whitespaces[['content']])
print(f"Jumlah baris yang mengandung whitespaces: {len(rows_with_whitespaces)}\n")

print("Baris yang mengandung angka di kolom 'content':")
print(rows_with_numbers[['content']])
print(f"Jumlah baris yang mengandung angka: {len(rows_with_numbers)}\n")

# Menampilkan data dengan indeks 2494, jika ada
def check_and_print(index, df):
    if index in df.index:
        print(f"Data pada indeks {index}:")
        print(df.loc[index, 'content'])
    else:
        print(f"Data pada indeks {index} tidak ditemukan atau tidak memenuhi kondisi.\n")
# Out:
# Baris yang mengandung link di kolom 'konten_ulasan':
# Empty DataFrame
# Columns: [content]
# Index: []
# Jumlah baris yang mengandung link: 0
#
# Baris yang mengandung simbol di kolom 'content':
#                                                 content
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 6     Sekrang tranfer dr BCA ke blue sesama BCA kena...
# 8                                     sangat² membantu😊
# 9     Blu ini udah bagus, dari segi administrasinya ...
# 10    Lambat sekali untuk setiap klik butuh 3 detik ...
# ...                                                 ...
# 5165  Saya tidak mengerti dengan review jelek aplika...
# 5166  Isi saldo nya bisa. Kenapa pas mao lakuin tran...
# 5167                                Apakah sudah bisa ?
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
#
# [2743 rows x 1 columns]
# Jumlah baris yang mengandung simbol: 2743
#
# Baris yang mengandung whitespaces di kolom 'content':
#                                                 content
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5168                                        sangat baik
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [4416 rows x 1 columns]
# Jumlah baris yang mengandung whitespaces: 4416
#
# Baris yang mengandung angka di kolom 'content':
#                                                 content
# 9     Blu ini udah bagus, dari segi administrasinya ...
# 10    Lambat sekali untuk setiap klik butuh 3 detik ...
# 19    meresahkan terlalu ribet buat ganti nomor aja ...
# 24      Tf dari bca ke blu bca jadi bayar 2500. Malesss
# 31    Maaf sudah waktunya tutup blu, sama2 bank bca,...
# ...                                                 ...
# 5130  otentifikasi wajah bikin ribet, sering gagal, ...
# 5132  Versi 1.43.0 dari aplikasi ini masih terasa la...
# 5151                              bagus keren bintang 5
# 5158  Mulai Langkahmu Buka Rekening di blu dengan re...
# 5160  Kasih bintang satu dulu nanti kalo di ACC lgsg...
#
# [592 rows x 1 columns]
# Jumlah baris yang mengandung angka: 592

# %%
df.info()  # Informasi tentang tipe data dan jumlah nilai non-null dalam setiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5174 entries, 0 to 5173
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              5174 non-null   object
#  1   userName              5174 non-null   object
#  2   userImage             5174 non-null   object
#  3   content               5174 non-null   object
#  4   score                 5174 non-null   int64
#  5   thumbsUpCount         5174 non-null   int64
#  6   reviewCreatedVersion  4409 non-null   object
#  7   at                    5174 non-null   object
#  8   replyContent          5174 non-null   object
#  9   repliedAt             5174 non-null   object
#  10  appVersion            4409 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 444.8+ KB

# %%
# Menghapus kolom yang tidak diperlukan untuk analisis
df = df.drop(columns=[
    'reviewId', 'userName', 'userImage', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion'
])
df.head()
# Out:
#                                              content
# 0                                             ok lah
# 1                                       mantap pisan
# 2                                   sangat memuaskan
# 3  Transfer BCA ke Blu pake biaya admin, jd males...
# 4                        Mudah prosesnya tpi gak acc

# %%
import re
# Menghapus karakter '@' dari content_remove_link
df['content_remove_at'] = df['content'].apply(lambda x: re.sub(r'@', '', str(x)))
df
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [5174 rows x 2 columns]

# %%
# Menghapus link dari data content
df['content_remove_link'] = df['content_remove_at'].apply(lambda x: re.sub(r'http\S+|www.\S+', '', str(x)))
df
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                     content_remove_link
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [5174 rows x 3 columns]

# %%
import re
df['content_remove_simbol'] = df['content_remove_link'].apply(lambda x: re.sub(r'[^\w\s.,!?]', '', x))
df
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                     content_remove_link  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_simbol
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [5174 rows x 4 columns]

# %%
# Menghapus data angka dari kolom 'content_remove_simbol' dan menyimpannya ke kolom 'content_remove_angka'
df['content_remove_angka'] = df['content_remove_simbol'].apply(lambda x: re.sub(r'\d+', '', x))

df
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                     content_remove_link  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_simbol  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                    content_remove_angka
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [5174 rows x 5 columns]

# %%
def remove_extra_spaces(text):
    return re.sub(r'\s+', ' ', text)

df['content_remove_spaces'] = df['content_remove_angka'].apply(remove_extra_spaces)
df
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                     content_remove_link  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_simbol  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                    content_remove_angka  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_spaces
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5169             meski dak pakai kartu blubca ttp keren
# 5170                                             mantap
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [5174 rows x 6 columns]

# %%
print(df.duplicated().sum())  # Menampilkan jumlah data duplikat
# Out:
# 635

# %%
# Mengatasi duplikasi
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())  # Menampilkan jumlah data duplikat
# Out:
# 0

# %%
# Validasi data
df  # Memeriksa data setelah tahap pembersihan
# Out:
#                                                 content  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                       content_remove_at  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                     content_remove_link  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_simbol  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                    content_remove_angka  \
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
#                                   content_remove_spaces
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [4539 rows x 6 columns]

# %%
# Ambil hanya kolom 'content_remove_spaces'
df = df[['content_remove_spaces']]
df
# Out:
#                                   content_remove_spaces
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [4539 rows x 1 columns]

# %%
# Mengganti nama kolom untuk konten yang telah dibersihkan
df = df.rename(columns={'content_remove_spaces': 'content'})

# %%
df
# Out:
#                                                 content
# 0                                                ok lah
# 1                                          mantap pisan
# 2                                      sangat memuaskan
# 3     Transfer BCA ke Blu pake biaya admin, jd males...
# 4                           Mudah prosesnya tpi gak acc
# ...                                                 ...
# 5167                                Apakah sudah bisa ?
# 5169             meski dak pakai kartu blubca ttp keren
# 5171  Gmnh bos klo udh punya akun tpi lupa email sam...
# 5172  Keren bangak bonusnya dan bunganya. Transfer j...
# 5173                       Mantap dapat cash back terus
#
# [4539 rows x 1 columns]

# %%
# Memeriksa total data setelah menghapus tanda baca dan spasi tambahan
total_data = df.shape[0]
print("Total data setelah penghapusan tanda baca dan spasi tambahan:", total_data)
# Out:
# Total data setelah penghapusan tanda baca dan spasi tambahan: 4539

# %%
# Menyimpan data yang telah dibersihkan
df.to_csv('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/CleanedBluBCA.csv', index=False)
