# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.11/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.11/dist-packages (from Textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (4.67.1)

# %%
from textblob import TextBlob

# %%
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/ProsessedJago.csv'

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.12.14)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2025.1.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.6 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 13.8 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.2 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2025.1.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.7 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.6 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=687c75ecc943977748c109e626173f9388cb69930cbaa764523cedfb7867ee8a
#   Stored in directory: /root/.cache/pip/wheels/81/f2/e0/d578821d723b473d18610ea93810e4a5402463919f07e603d9
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai 1.59.6 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# langsmith 0.2.10 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2025.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# Importing library yang dibutuhkan
import googletrans
from googletrans import Translator

# %%
data = pd.read_csv(data_path)
data.head()
# Out:
#                                 content_normalisasi2
# 0                              kebanyakan eror takut
# 1  jago yg kau udah login masaan udah bolak ngela...
# 2                    bank jago emang jagoan mantappp
# 3  penyelesaian profesional rekening diambil alih...
# 4                                               good

# %%
translator = Translator()
translations = {}
for column in data.columns:
    # Unique elements of the column
    unique_elements = data[column].unique()
    for element in unique_elements:
        # Adding all the translations to a dictionary (translations)
        translations[element] = translator.translate(element).text
translations
# Out:
# {'kebanyakan eror takut': 'most errors are afraid',
#  'jago yg kau udah login masaan udah bolak ngelapor gak titik terang nya nya gak pake rekening nya': "It's good that you have logged in for a while and have been reporting, the bright spot is that you don't use the account",
#  'bank jago emang jagoan mantappp': 'A good bank is really a good one',
#  'penyelesaian profesional rekening diambil alih orang kasihkan bukti kuat penjelasan lapor polisi hasilnya memuaskan rb biarkan jtan': 'professional settlement of accounts taken over by people, provide strong evidence, explanation, report to the police, satisfactory results, RB, let Jtan',
#  'good': 'good',
#  'nyaman mudah terpercaya': 'comfortable easy reliable',
#  'udah transaksi ko pinjaman muncul ya': 'How come the loan transaction has appeared?',
#  'aplikasi ribett': 'complicated application',
#  'bagus pengiriman cepat': 'good fast delivery',
#  'rekomended': 'recommended',
#  'bank aneh ngasih bonus rb lho gimana pakai fiturnya': 'strange bank gives a bonus of rb, you know how to use the feature',
#  'pemakaian mudah cepat': 'fast easy use',
#  'bagus': 'Good',
#  'tinggal privikasi wajah tapik loading': 'Just keep your face private while loading',
#  'best app nabung': 'best savings app',
#  'puas': 'damage',
#  'kaka laporan pembaruan no bank jago alamatnya dimana iya sby nomor yg dftrin uda kehangus bank jago dlu uda ak uninstall dfr nik uda pernh kepakai iya': "Kaka, update report on Bank Jago's number, where is the address, sir, the registered number has been burned, Bank Jago, I have uninstalled DFR Nik, have you ever used it?",
#  'alhamdulillah bagus banget aplikasinya membantu fitur dompet nya dipisahpisah': 'Thank God, the application is really good and helps separate the wallet features',
#  'kecewa kerusakan hp pake hp verifikasi hp gimana verifikasi hpnya aja rusak': 'Disappointed with cellphone damage using cellphone verification, how to verify that the cellphone is damaged',
#  'edit': 'edit',
#  'ka lupa sandi nomernya hilang jdi login tolong bantu': 'If you forgot the password, the number is lost so login please help',
#  'sengaja kasi bintang biar liatan gimana ya mksd nya akun aja kunciblokir penjelasan megang hp seharian mohon jago bank memiki akun jago bank kuncidi blokir tolong jago bank membuka kunci blokiran keamanan benarbenar trimakasih': 'I deliberately gave it a star so you can see what it means, just lock the account, explain how to hold your cell phone all day, please be good at the bank, have a good account, the bank will lock it, please be good at the bank, unlock security blocks, really, thank you',
#  'tingkatkan kualitas': 'improve quality',
#  'kecewa pelayanan c jago tolong solusi keamanan lupa pertanyaannya berbelitbelit solusi apapun cocok': 'Disappointed, C service is great, please help with a security solution, forget the question is complicated, any solution is suitable',
#  'membantu': 'help',
#  'daftar download nik kepakai jago': 'register for downloading nik using jago',
#  'ktp diterima akun blokir kirim ulang ktp prosesnya udah diblokir penjelasan memuaskan': 'ID card received, blocked account, resend ID card, process has been blocked, satisfactory explanation',
#  'oke': 'limit',
#  'simpelmudah lancarkan transaksi': 'simple, easy to carry out transactions',
#  'bang jago kemudahan kena hacker penipu berkeliaran salah korban penipu aja download registrasi dibank jago tau tau no nik kepakai bank jago bank jago parah': "Bro, Jago, it's easy to get scammed by hackers roaming around, it's wrong to be a victim of fraudsters, just download registration at Jago Bank, you know the NIK number, use Jago Bank, Jago Bank is bad",
#  'aplikasi susah akun blokir susah ampun buka blokiran nyaa saldonya sampe dibuka blokiranya saldo': 'the application is difficult to block accounts, it is difficult to effectively unblock the balance until the balance is unblocked',
#  'oky': 'ok',
#  'rekomended bank digital promo': 'digital bank promo recommendations',
#  'ok mantul membantu': 'ok that helps',
#  'mantap': 'solid',
#  'akun ga akses nomor hp ilang sandi lupa tolong login pake email ga no hp': "account can't access cellphone number lost password forgot please login using email not cellphone number",
#  nan: 'in',
#  'ok ko': "i'm ok",
#  'mudah terpercaya': 'easy to trust',
#  'parah ni bank jago akun gw d blokir tlf costumer service nya nya d suruh tf dlu tp d buka saldo nya nyangkut gak': "This is really bad, my bank account has been blocked by the customer service phone, I told them to call TF first, but when I open the balance, it's still stuck or not.",
#  'top': 'top',
#  'bang jago memuaskan udah mengunakan nya': "Bro, I'm very satisfied with using it",
#  'mempermudah transaksi bangett': 'makes transactions really easy',
#  'ok': 'ok',
#  'customer service ajar lgi diskusikan ku yg lupa password id telpon langsung blokir': 'Customer service taught me to discuss it. If I forgot my telephone ID password, I immediately blocked it',
#  'ok mantap bank jago': 'OK, great, good bank',
#  'aplikasi keuangan yg simple bagus': 'good simple financial application',
#  'gimana ganti no hp hilang': 'how to change lost cellphone number',
#  'hallo bang jago kebingungan nih masuk akun ga aja gimana ya gara gara pindah hp abis direstar': "Hello bro, I'm confused about how to log in to my account because I moved my cellphone after restarting it",
#  'transfer gangguan coba udh dicoba jam aja gagal gimana sihh tolong dibenerin tf gabisa': "I've tried the transfer problem, I've tried it for hours but it doesn't work, how can I fix it, but it doesn't work",
#  'aplikasi bagus': 'good app',
#  'lemot': 'slow',
#  'applikasih mudah gk pakai ribet': 'Easy application, no hassle',
#  'bikin kartu atm nya': 'make an ATM card',
#  'saldo gopay sy hilang gara update gopay tabungan by jago cek bang jago kagak gopay kagak bantu min': 'my gopay balance is lost because of update gopay savings by master check bang master not gopay not help min',
#  'masuk kode sm nomor telepon aktif lupa mengganti nomor tolong bantu masuk akun akses email': 'enter sm code active telephone number forgot to change number please help enter email access account',
#  'ko pasword nya ga buka sy suruh masukin no hp sm nik sm ajh gak buka': "How come the password doesn't open, I tell you to enter your cellphone number and Nik, but it doesn't open",
#  'ribet login nya hpku rusak pake hp satunya gak login': "It's complicated logging in, my cellphone is broken and the other cellphone won't log in",
#  'parahkemarin aplikasi negbugsaya top up gopay ribuan kali saldo masuktapi saldo terpotong ribudan katnya transaksi memotong saldobayangkan uang jutaanapa gak hilang uang': 'Worse, yesterday the application was good at top up Gopay thousands of times the balance came in but the balance was deducted by thousands and it said the transaction deducted the balance imagine millions of money or not losing money',
#  'ga ubah password masukan email no hp nik tetep gabisa': "If you don't change the password, enter email, Nik's cellphone number, it still doesn't work",
#  'kali aplikasi bermasalah repot bersihkan chance menerus kb aja prose pengajuan sanggahan lamaa banget kesalahan system tarik tunai gagal saldo berkurang nunggu sampe minggu tunggu konfirmasi bener temen aplikasi ga bagus recomend': "If the application has a problem, it's a hassle to clean the chance, just keep checking, the process of submitting an objection takes a really long time, the cash withdrawal system error fails, the balance decreases, wait until a week, wait for confirmation, really, friend, the application is not good, recommend",
#  'keamanan akun nasabah bank jago mohon bank jago memperbaharui verifikasi keamanan akun log in perangkat ganti password ganti pin mohon verifikasi otp sim card otp email nik keamanan verifikasi keamanan utama akun bank jago bergantung sim card sim card kloning duplikat orang': 'Bank Jago customer account security, please Bank Jago renew account security verification, log in device, change password, change pin, please verify OTP SIM card, OTP email NIK, security verification, main security of Jago Bank account, depend on SIM card, SIM card clone, duplicate person',
#  'mantap fleksibel bermanfaat': 'steady, flexible, useful',
#  'bagus bank jago': 'good good bank',
#  'memuaskan transaksi ngk bata jamdan atm lg lupa pindahkn gopay fleksibel': 'satisfactory transaction ngk brick jamdan atm lg forget to transfer flexible gopay',
#  'blum coba nabung': "Haven't tried saving yet",
#  'mantap ok bonusnya': 'great, okay bonus',
#  'apk mantap': 'great apk',
#  'mantap thanks bonus k nya': 'great, thanks for the bonus',
#  'alhamdulillah transaksi aman mudah cepat': 'Thank God, the transaction was safe, easy and fast',
#  'transaksi cepat': 'fast transaction',
#  'susah': 'hard',
#  'bug login hp direset diservice': 'HP login bug reset at service',
#  'selamat siang gimana merubah data nik ktp terdaftar dibank jago sya mendaftar nik ktp sya terdaftar': 'Good afternoon, how do I change my registered ID ID data at Jago Bank, I registered my ID card registration',
#  'mantul fitur atur jadwal transfer': 'Helps to set transfer schedule feature',
#  'jago service is not a good a before it slow and ha many shortcoming nowkartu debit gak kepakai zonkincreasing level jago lambat mengecewakan': 'jago service is not a good one before it was slow and only a lot of short coming now debit card not used zonkincreasing level jago slow disappointing',
#  'jago mbantukartu debit zonk jadinyamafkurang fleksibel kenaikan level jagoan free transfer nunggu lamaperìode upgrade limit tgl terlewat tgl gak seĺesai² rekening jagoan gak increase level not in accordance with the initial agreement the requirement for the increase on date the st should be increased quickly not continuously delayed so pending melulu gak naek level syarat kenaikan terpenuhi semuak': "jago helps with zonk debit cards so it's not flexible enough to increase the level of jagoan free transfer long wait period upgrade limit date is late the date is not complete the jagoan account doesn't increase level not in accordance with the initial agreement the requirement for the increase on date the st should be increased quickly not continuously delayed so pending just not increasing the level, all the requirements for the increase are met",
#  'bagus tambahan coba sediain qris merchant bank jago lengkap': "It's a good addition to try providing a complete QRIS Merchant Bank Jago service",
#  'bank jago bagus': 'good bank',
#  'banik': 'the merchant',
#  'the best': 'the best',
#  'apk yg bagus': 'good apk',
#  'satset': 'the bet',
#  'ganti hpapk ga digunain': "Replacing HPAPK doesn't work",
#  'very good': 'very good',
#  'gue login gabisa bangsatt hapus login ngeribetin orang udah gabisa login': "I can't log in, damn it, deleting the login is scary, people can't log in anymore",
#  'awesome': 'awesome',
#  'bantu aktifkan fitur pinjaman bank jago': 'help activate the jago bank loan feature',
#  'error mulu masuk ribetnya ampun': 'The errors keep getting in the way, sorry',
#  'uang hilang bank jago mohon tanggung': 'Money lost, good bank, please take responsibility',
#  'x iklanmu': 'x iklanmu',
#  'lupa pasword ribet masuknya pemulihannya': "Forgot the password, it's complicated to enter and recover",
#  'mantab': 'great',
#  'no comen': "they don't eat",
#  'ga nyangka jago anti ribet anti zonkkkk': "I didn't expect to be good at anti-complicated anti-zonkkkk",
#  'login': 'login',
#  'refund sy ga masuk maximal kerja dimintain keterangan ngilang ga dibales emailnya hahaaha jago profesional bgd': "My refund didn't go to maximum work, I was asked for information about missing, no response to my email hahaaha, really good professional",
#  'login aja ribet keamanannya lebay banget': 'Just logging in is complicated, the security is really bad',
#  'bikin transaksi gampang mudah': 'make transactions easy',
#  'mantap jiwa pokoke': 'steady soul',
#  'aplikasi aman gak sih ktp gue pertamakali pake nih apk': "Is the application safe? It's my first time to use this apk",
#  'aplikasi bermanfaat': 'useful application',
#  'membantu gk no rekening': 'does the account number help?',
#  'mengurus pergantian nomor susah telpon jago jawabannya template suruh nunggu suruh nunggu melulu kejelasan ditindaklanjuti dihubungi jam kerja udah berhari dihubungi katany suruh tenang tenang tenaaaaang beneran kerja ga sih karyawannya': 'arranging a number change is difficult, the telephone is good, the answer is the template, telling me to wait, telling me to wait, just clarity, follow up, contacted working hours, been contacted for days, he said, told me to calm down, calm down, are the employees really working?',
#  'parah saldo bang jago susah masuk': "It's really bad, bro, it's hard to get your balance in",
#  'bagus layak': 'good worth it',
#  'recomended banget': 'really recommended',
#  'parah banget nih nggk login hapus data gopay login bang jago nyesell udah sambungin gopay': "It's really bad, I can't log in, delete my GoPay login data, Bro, I'm sorry I connected GoPay",
#  'bank jago emang jago': 'good banks are really good',
#  'bank digital ko gak ikuti jaman vermuk knpa pake kode otp no hp kalo no hp gak aktif gmna nasib akun nya kacau': "Why don't digital banks follow the Vermuk era? Why do you use an OTP code for your cellphone number? If your cellphone number isn't active, what happens to your account being messed up?",
#  'hati hati gaes bank jago amanah tf via qris broker exness dana kirimkan manipulasi bank jago': 'Be careful guys, Bank Jago Trusted TF via QRIS Broker Exness funds, send Bank Jago manipulation',
#  'jago pinjaman muncul': 'the loan expert appears',
#  'bank jago aman transfer all bank gratis admin': 'Bank Jago secure transfers to all banks, free admin',
#  'borcode qris nya tolong tampilkan dg mudah ya biar gaptek langsung tau penggunaan nya': 'Please display the QRIS barcode easily so that the tech-savvy can immediately know how to use it',
#  'bagus transaksi mudah': 'nice easy transaction',
#  'jam login salah untung belom takutnya aja data yg dah akun disalah': "Wrong login time, luckily I'm not afraid of the data in my account being wrong",
#  'engk regesrtrasi ktp': 'regesrtrasi ktp',
#  'bagus banget': 'really good',
#  'bagus memudahkan': 'nice makes it easier',
#  'kecewa layanan bank jago berbelitbelit bersahabat penyandang disabilitas bolakbalik counter mencetak surat pernyataan penggantian nomor handphone terkunci aplikasi isi nik nomor hp scan wajah udah nomor pin berubah setahuku ganti nomor pin mohon dibenahi layanan': "Disappointed, the bank's service is convoluted, friendly to people with disabilities, going back and forth over the counter, printing a statement letter for changing the cellphone number, the application is locked, fill in the nick, cellphone number, scan the face, the pin number has changed, as far as I know, change the pin number, please fix the service",
#  'aplikasinya mudah dipahami fitur yg bermanfaat fitur auto budgeting mantap deh pokoknya': 'the application is easy to understand, the features are useful, the auto budgeting feature is really great',
#  'selasa januari wib hubungan aplikasi mengajukan hapus data memohon aplikasi hapus data pribadi menyalahgunakan data pribadi bertanggung terimakasih': 'Tuesday January WIB application connection request to delete data request application to delete personal data misuse of personal data is responsible, thank you',
#  'skema ponzi jahat': 'evil ponzi scheme',
#  'sorry gw turunin gw udah ngasih saran biar milih kode otp dikirim email no telp blm fitur kalo kehilangan sim card repot ngurusnya': "sorry, let me down. I've given you advice so that you can choose an OTP code, send an email, telephone number, no feature, if you lose your SIM card, it's a hassle to take care of it.",
#  'suka bgt': 'really like it',
#  'memuaskan transfer gratis biaya transfer top up e walet biaya admin beli pulsa paketan murah aplikasi m banking digital gangguan aman terpercaya': 'satisfying transfers, free transfer fees, e-wallet top up, admin fees, buy credit in cheap packages, digital m banking application, secure and reliable disruption',
#  'apk bagussemoga kedepannya bagus sukses bank jago': 'good apk, hopefully the future will be good and successful, Jago Bank',
#  'bank meresahkan gaudah download bank bank sok agamis maling duit nasabah nya bank burukjahat hidup semoga keluarga dibank terkena musibah': "The bank is worrying about not downloading the bank. The bank that pretends to be religious steals its customers' money. The bank is bad. Evil lives. May the family at the bank be affected by disaster.",
#  'mending pake bank jago timbang gopay goay ngelag ngelag': 'better use bank good than gopay goay lag lag',
#  'eorr gakbisa loginpadahal pasword sma email udh trus dgn saldo yg apk gak ambil': "eorr can't log in even though the password and email are already there and the balance that the APK doesn't take",
#  'mudah praktis bank digital terbaik pertahankan free transfer semoga pilihan transaksi': 'easy, practical, the best digital bank maintains free transfers, hopefully transaction options',
#  'aplikasi aneh login hp mlh g setujui perangkat pdhl sy complain c nya hasilnya aja disuruh verifikasi tolol bngt kasih tau pdhl klo hp jual disuruh verifikasi hp nama aja bank jago aslinya mah bego buktinya bantuan login verifikasi ktpemailnomorvc tetep setujui perangkat': "strange application for logging in to your cellphone and it doesn't approve the device even though I complained about it, the result is that you're told to verify it's really stupid, let me know, even if you sell the cellphone, you're told to verify the cellphone, the name of the bank is really good, the real one is stupid, the proof is, help login, verify ktpemailnomorvc, still approve the device",
#  'baiknya bank jago dikasih jaminan sprt gopay oatau dana transfer uangnya terkirim kurun nasabah dpt kompensasi kemarin transfer uang dri jago bri smp uangnya masuk rekening': "It's good that Jago Bank is given a guarantee such as GoPay or the money transfer funds are sent when the customer gets compensation. Yesterday, the money transfer from Jago BRI was sent until the money entered the account.",
#  'membantu aegala urusan': 'help with all matters',
#  'bermanfaat': 'beneficial',
#  'suka jago fiturnya lengkap anti ngelag transaksi gampang': 'I like it, it has complete features, anti-lag, easy transactions',
#  'bank jago mempertimbangkan kenyamanan nasabahproses penggantian nomor telepon sederhana dokumendan kecewa layanan c bank jagotidak respon bantuan mengecewakan': "Bank Jago considers customer convenience, the process of changing telephone numbers is simple, documents and is disappointed that Bank Jago's C service does not respond to help, which is disappointing",
#  'promo kadang gimik ajasudah sesuai dapatharus follow up itutetapi zonkmengecewakan': 'Sometimes promos are just gimmicks and they are appropriate, you have to follow up, but the results are disappointing',
#  'kode otp udh diketik timer ttp berjalan gabisa login udh diulanh berkali kali ttp aja': "OTP code has been typed, timer still running, can't log in, repeated several times but still",
#  'amazing': 'amazing',
#  'sagat': 'hour',
#  'sengaja bintang dibaca pembayaran qrins bayar belanjaan saldo berkurang penerima menerima uang refund pembayaran lapor bank jago via mail uang kembalikan teman penguna bank jago hati u tuk bertransaksi gagal pembayaran uang hangus gak yg mengalami': 'Accidentally read the star, qrins payment, pay for groceries, the balance is reduced, the recipient receives the refund money, report the payment to Bank Jago via mail, return the money to friends who use Bank Jago, be careful if the transaction fails, the money is forfeited, is there anyone who experiences this?',
#  'bagus atur keuangan aplikasi nya lumayan cepat': "It's good to manage your finances, the application is quite fast",
#  'semoga acc': 'hopefully acc',
#  'login ya ya lupa pasword pemulihan email nik koneksi bermasalah mendaftar tertolak nik jenis bank jago': 'login yes yes forgot password recovery email Nik connection problem registration rejected Nik type jaja bank',
#  'kerenn': 'cool',
#  'login aja ribet banget dilempar udah mendukung valid log in karna hp rusak jgn deh pake apk gesss hangus uang': "Just logging in is really complicated, it was thrown out, it supports valid login because the cellphone is broken, don't use the gesss apk, you will lose your money",
#  'ribet no yg terkait hilang susah login solusi berbelit belit suruh telpon pulsa k sedot beres suruh kirim email pa dapet email isi sampe ttd matrai udah tau no hp hilang ttp verifikasi no yg hilang': "It's complicated, the related number is lost, it's hard to log in, the solution is convoluted, I'm told to call credit, suck it up, I'm told to send an email, I get an email with the contents until the matrai sign, I already know that the cellphone number is lost, but verify the lost number.",
#  'buruk login sinyal full': 'bad login full signal',
#  'bgus verifikasi gampang': 'great, easy verification',
#  'si gangguan bayar qris aja gabisa top up tf susah karna bermasalah tolong yaa diperbaiki': "The problem with paying QRIS is that I can't top up TF, it's difficult because it's problematic, please fix it",
#  'coba masuk akun jago menerus bilang gangguanini sih': 'Try logging into your Jaja account and it keeps saying this is a problem',
#  'membantu mudah': 'easy help',
#  'x kali transaksi qris status pending masuk merchant pa status sukses merchant menerima pembayaran uang direfund complain slowresp ribet': 'x times qris transaction pending status entered merchant pa success status merchant received money refunded complaint slow response complicated',
#  'tgl tolong hapus data masuk aplikasi persulit habis masukkan data masuk lagikalau data salah laporkan ojk berwajib maksudnya aplikasi bank jago gimanasaya pinjam cek bi pinjaman aktif pinjam': 'date, please delete the application entry data, make it difficult to finish entering the entry data again, if the data is incorrect, report it to the OJK authorities, meaning the bank application is good, how can I borrow a check, active loan borrowing',
#  'ga verifikasi': 'not verified',
#  'bestt bgtt ramah apk ny jg bagus makasi udh bantuin login td': "The apk is really friendly, it's also good, thanks for helping me log in",
#  'it great': 'it great',
#  'minggu kemarin download jago hpus krna ga isi saldonah pa kemarin download lgi pa login notifikasi nya diperangkat perangkat mna org sya doang yg download dihp suami mah ga download yahpus data kalo yg mengatasnamakan sya sya bertanggung yg oknum yg tdk bertanggung jgaakan sya laporan yg': "Last week I downloaded Jago HPUS because it didn't top up my balance. Well, yesterday I downloaded it again and logged in. The notification is on which device, which person is the only one who downloads it on my husband's cellphone, but he doesn't download the data, if it's in my name, I'm responsible for the irresponsible person, so I won't report anything wrong.",
#  'suka aplikasi inisangat menguntungkan apapun': 'I like this application, it is very profitable in any way',
#  'jago baguuus': 'really good',
#  'sat set lsncar': 'sat set lsncar',
#  'keren fiturnya lengkap': 'cool, complete features',
#  'simpan uang terbaik bunga bulanan': 'save money best monthly interest',
#  'neobank terbaik': 'best neobank',
#  'berat aplikasinya': 'heavy application',
#  'c nya aktif membantu terima kasih': 'c is actively helping, thank you',
#  'aplikasi nya jelek ganti hp gabisa login password emailnya bener': "The application is bad, changing the cellphone can't log in, the email password is correct",
#  'mengecewakan sistem loginnya berbelittidak bank digital dg password otp mengecewakan pilih ga ribet aja': "Disappointingly, the login system is complicated, not a digital bank with an OTP password, it's disappointing, just choose not to be complicated",
#  'apk nya udah bagus gampang dipakai salah kartu langsung dipotong k dikasih pemberitahuan rugi banget dipotong minimal kasih pemberitahuan biar pengguna tau kalo salah mohon diperbaiki merugikan pengguna': "the apk is good, it's easy to use, if the card is wrong, it's immediately cut, given a notification, it's really a loss, it's cut, at least give a notification so the user knows, if it's wrong, please fix it, it's detrimental to the user",
#  'kembalikan uang': 'return money',
#  'ribet salah masukan sandi langsung dikunci akun nunggu jm lgi login lgi': 'If you enter the wrong password, your account will immediately be locked, waiting for you to log in again',
#  'sangan puas dgn apk memudah bertransaksi gratis biaya adm nya': 'Very satisfied with the easy transaction apk with free admin fees',
#  'dear developer i think there is a bug that you should pay attention to in the jago syariah faq menu section please fix it to make it easier for u to access': 'dear developer i think there is a bug that you should pay attention to in the jago syariah faq menu section please fix it to make it easier for u to access',
#  'memuaskanfitur lengkapkeamanan kuatapalagi suda gabung gopay pa banget tambh sukasukses bank jago': 'Satisfying, complete features, strong security, especially if you have joined GoPay, it really adds to the success of a good bank',
#  'bilang pelayanan pengiriman bank jago memuaskan sy dlu akun bank jago bank aladin bank aladin gratis sampainya dibandingkan bank jago bayar k gimana pelayanannya yg berbayar tanggap gk sih saran sy bank jago jasa kurir ninja express jasa pengiriman ampas kasihan orang yg jawa nunggu gk dihubungi kurirnyaambil gk': "I said that Bank Jago's delivery service was satisfactory to me. First of all, Bank Jago's account, Bank Aladin, Bank Aladin, arrived free compared to Bank Jago, how is the paid service, responsive or not, my advice, Bank Jago, Ninja Express courier service, dregs delivery service, I'm sorry for the Javanese people who are waiting and the courier hasn't contacted them or not.",
#  'nomer hilang lupa': 'lost number forgot',
#  'kalo perangkat sdh matot gimana verifikasi coba prtanyaan utk verifikasi dgn memilih prtanyaan yg blm dlm aplikasi bi cheking riwayat pinjaman dr bank jago gak peminjaman atopun kredit': "If the device is dead, how to verify it? Try asking questions for verification by selecting questions that are not in the application, check your loan history from a good bank, whether it's lending or credit.",
#  'kepastian': 'certainty',
#  'ribet login': 'complicated to log in',
#  'apl sampah': 'rubbish app',
#  'meng keren pokoknya': "it's really cool",
#  'error login pin password bener pa diganti password password lahh kocak pa login gak pa diganti langsung login tetep gak jujur jago mudah praktis enak kedepannya memakai bank': "login error, pin password, correct password, change password, it's funny, login, no change, log in straight away, still not honest, good, easy, practical, nice in the future, using a bank",
#  'nasabah bang jago blokir tau apk wa nya arahin email jago nya tim bla bla bla ya uang nyangkut bkn rejeki': 'customer bang master block know apk wa his direct email master his team blah blah blah yes money stuck not fortune',
#  'allah nyebelin banget masuk aja dipersulit taiiiii lu': "god it's so hard to get in, just don't make it difficult for you",
#  'aplikasi rusak': 'application is broken',
#  'liat komen dimohon bank jago ribet menarik saldo berkala akun bank jago gua kunci jam selesai gak gua install ni apk terparah gua install narik bank jago gak recommended ygy': "Look at the comments, I asked Jago Bank, it's complicated to withdraw the periodic balance of my Jago Bank account, I locked it when I finished, didn't I install this, the worst apk I installed, I installed Jago Bank, it's not recommended, Yangy",
#  'akun bang jago lupa sandi mohon bantuin min': 'bro, good account forgot password please help min',
#  'bagus nyaman pake bank jago nya belanja pake debit plus tarik tunai atm gratis cepat': 'good, comfortable using a good bank, shopping using debit plus fast free ATM cash withdrawals',
#  'saldo ngilang k akibat menghubungkan kartu debit aplikasi dana pengambilan saldo k refund kembalikan cek aplikasi bank jago gak rincian riwayat saldo kejadian male nabung bank jago ngeri saldo tari au to uninstal applikasi': 'balance disappeared due to linking debit card fund application withdrawing balance k refund return check bank jago application or not details of balance history incident male savings bank jago horror dance balance au to uninstall application',
#  'jos semoga g ribet': "Jos, I hope it's not a hassle",
#  'aplikasi lancar dah fleksibel pembayaran': 'Smooth application and flexible payment',
#  'buruk perangkat hp rusak mati total login hp muncul dicoba mohon solusinya ubah bintang solusi yg': 'bad cellphone device is damaged completely dead cellphone login appears try please change the star solution',
#  'akun dibuka yg pakai pakai anehhhhhh': 'The account was opened using a strange use',
#  'ga mudah ganti nomor lupa nomer kartu ilang gitu ribet banget berkas': "It's not easy to change the number, forget the lost card number, it's really complicated to file",
#  'membantu perbankan': 'help with banking',
#  'tolong aktif pinjaman akun bank jago terima kasih': 'Please activate your Jago Bank account loan, thank you',
#  'halo kecewa dgn jago tambahan biaya admin free aaahh memakai thx u ya': 'hello, disappointed with Jago, additional admin fees are free, aaahh, thx for using',
#  'suka bank jago gak bertelesat set': "I like a bank that's good at not going too far",
#  'masuk ribet suruh verifikasi langkah hp nya hp gw rusak pa daftar gak tuh keamanan gimana sih bener aja kalo bikin aplikasi tu': "come in and tell me to verify the steps on my phone. My phone is broken. I don't register. How is the security? It's okay if I make the application",
#  'baikdan membantu': 'kind and helpful',
#  'transfer dompet tunai ribu ga masuk saldo jago nya berkurang cek riwayat transaksinya ga ga klaim': "Thousands of cash wallet transfers didn't go into the balance, the balance was reduced, check the transaction history, no claims",
#  'kebutuhan pendukung transaksi utk arah yg baikn begunan thank u jago piss': 'transaction support needs for a good and useful direction thank you jago piss',
#  'tolong tambahkan qris bayar telepon internet customer service langsung aplikasi jago': 'Please add QRIS to pay internet telephone customer service directly to the Jago application',
#  'bonus k': 'bonus k',
#  'promo nya menarik': 'the promo is interesting',
#  'parah skrg bank jago ga gguan d buka eror menghambat bgt transaksi': 'Are banks good at opening disruptions now? Errors really hinder transactions',
#  'c nya komunikatif lupa password semoga kedepannya aplikasi bank jago maju berkembang': 'Communicative c forgets the password. Hopefully in the future the Jago Bank application will develop',
#  'kecewa liat aplikasi bank jago pa login akun mntak verifikasi langkahsedangkan akun terkonek handphone aja email c cobak telpon call center nya tindakan kejadian nya semenjak update bank jago fitur verifikasi langkah bikin sulit login akun akun orang': "Disappointed to see that the Bank Jago application, login to the account, asks for step verification, while the account is connected to the cellphone, just email C, try calling the call center, the action has happened since the Bank Jago update, the step verification feature makes it difficult to log in to people's accounts.",
#  'semoga dipermudah berbuat amal isnpirasi amal jariyah aamiin': 'Hopefully it will be easier to do good deeds, inspiration for good deeds, aamiin',
#  'gk ngajuin pinjaman pa kredit motor terdetek pinjaman bank ayolah pakai data orang sembarangan pck': "Don't apply for a loan on motorbike credit, bank loan was detected, come on, use random people's data, PCK",
#  'lupa pasword gimana': 'forgot the password',
#  'terima kasih bang jagokau permudahkan urusankunggk pergi konter pln lagiselesai mudah cepat urusan transaksi uangan': "Thank you, bro, you made things easier for me, I didn't go to the PLN counter anymore, it was easy and quick to complete the money transaction",
#  'aplikasi blm udh parah aplikasi ny maling saldo konfirmasi dlu parah': "The application hasn't started yet, it's already serious, the application is stealing confirmation balances, it's already serious",
#  'tolong bantuannya login semenjak ganti hp gara salah pasword pasword benerin verifikasi langkah gimana ngaktifin ganti hp tolong turunin bintangnya aplikasi bintangnya terimakasih': 'Please help, login since I changed my cellphone due to wrong password, correct password, verify steps, how to activate cellphone change, please lower the stars, star application, thank you',
#  'ganguan dibuka apk notif ganguan harap tunggu sebentar ya berjam jam buka masi muncul notif tolong diperbaiki': 'trouble opening apk, trouble notification, please wait a moment, after hours of opening, the notification still appears, please fix it',
#  'knp nabung uang saldo': 'why save money?',
#  'jelek nomor rekening terhubung bibit pa masuk login keapikasi gak gak tau udah melapor email wa telpon g tindak ga de pake aplikasi bank skip bener bener gak': "the account number is bad, the seed is connected, how can I enter the login, I don't know, I have already reported the email, I called, I didn't do it, I don't use the skip bank application, is it true?",
#  'm a n t e p': 'm a n t e p',
#  'sulit masuk ktp terdafttar': 'Difficult to enter registered ID card',
#  'bikinpasword sandi akun salah gimana ceritanyajangan penipuan gaes yg belanja pinjam uangkita yg tagih parah ni aplikasi buruk': "Make the account password wrong. What's the story? Don't be a fraud, guys who shop and borrow money. We're the ones who charge badly. This is a bad application",
#  'aplikasi nya memuaskan bantu menyimpan uang': 'The application is satisfying and helps save money',
#  'merubah email nomer hp tertaut akun kehilangan jd bantu': 'Changing the email cellphone number linked to the lost account will help',
#  'hp hilang dicuri mohon bantuan login': 'cell phone lost stolen please help login',
#  'menyesali nggak logoin': 'regret not logging in',
#  'login terima kasih': 'login thank you',
#  'hilang uang transaksi tokped via visa jaringan lemot dibantu c jago sampe uangnya responnya cepet ramah csnya emang the best sih bank digital love you jago': 'Lost money on Tokped transaction via Visa, slow network, help from C, good at getting the money, fast response, friendly CS, really the best digital bank, love you, good',
#  'aplikasi sampah ribetnya ampun nih aplikasi': 'What a complicated rubbish application, sorry',
#  'gabung': 'join',
#  'min aplikasi jago ga fitur deposit syriah ya': 'Ask if the application is good at sharia deposit features',
#  'aplikasi sialan no nik ktp udh bener tolak mulu': 'The damn application for the NIK KTP number has been completely rejected',
#  'email tanyajago email no tlp aktif tpi responya email nomernya salah permasalahan nya login lupa pasword tulisanya kendala trus': 'email ask jago email the telephone number is active but the response is that the email number is wrong the problem is logging in forgot the password the writing is having problems then',
#  'aplikasi menyusahkan maunpindah hp ga ti': 'The application makes it difficult to switch phones',
#  'transaksi mudah senang bank jago': 'Easy transactions and good banking',
#  'bank favorit terafiliasi gojek gopay bibit stockbit pembuatan akun mudah': 'Gojek affiliated favorite bank Gopay Stockbit seeds Easy account creation',
#  'top markotop': 'top markotope',
#  'mengganti usulan yg kemaren karna uang udh terimakasih bang jago yg membantu kendala yg kemaren uang tiba² hilang terimakasih apk bang jago rekan² bang jago': "changed yesterday's suggestion because the money was already there, thank you, bro, who helped with yesterday's problem, the money suddenly disappeared, thank you, apk, bro, good, friends, bro, good",
#  'semoga pinjam': 'hopefully borrow it',
#  'mantab bagus banget': 'really good',
#  'kasih bintang dlu sandi mengubah nya nomor hape aktif k blokir mengubah nya gmail semoga bintang mengubah nomor telepon krna aktif blokir': 'Give me a star first, the password is to change the active cellphone number to blocked, change it to Gmail, hopefully the star will change the telephone number because it is actively blocked',
#  'memuaskan': 'satisfying',
#  'gk tolong dibaca review jawabanya suruh jelasin kendala via email eh dicek email intinya bank dipakai mending pindah bank gedungnya diseluruh indonesia gk recommend make bank': "No, please read the review, the answer is told to explain the problem via email, but check the email, the point is, the bank you are using, it's better to move bank buildings throughout Indonesia, don't recommend using a bank",
#  'udah ganti ganti nomor whatsap daftar aja persulit kode verifikasi uninstal gak nomor rekening': "I've changed my WhatsApp number, just register and make it difficult to uninstall the verification code or account number",
#  'code verification login keburu abis': 'The login verification code ran out in a hurry',
#  'jago syariah top': 'top sharia expert',
#  'menghapus akun in pengajuan d tolak menerima pinjaman bentuk apapun harap data d hapus': 'delete account in application and refuse to accept any form of loan, please delete data',
#  'kesal aplikasi pakai menyelesaikan langkah video call benarbenar merepotkan serius tolong lakukan': "annoyed that the application uses to complete the video call steps, it's really a serious hassle, please do it",
#  'kali akun ga kendala no email download apknya boro boro akun mohon diperbaiki permasalahan terulang': "Sometimes the account doesn't have problems with the email number, downloading the APK, boro boro account, please fix the problem again",
#  'gak masuk akun pelanggaran daftar esokan nya gak login email nik dibilang salah salah penipuan awas aja sampe nama ku jelek ojk ku laporkan polisi karna menyalah data orang izin': "I didn't log in to my account, violation of registration, the next day I didn't log in. Nik's email was said to be a mistake, it was a fraud, just be careful, until my name is bad, OJK, I will report it to the police because it's a violation of someone's permission data.",
#  'terkadang gangguan pa payment': 'Sometimes there are payment problems',
#  'penawaran limit menarik': 'Attractive limit offers',
#  'syariah': 'syariah',
#  'menonaktifkan tabungan jago dinomertelpon menyingkronkan akun gojek gopay plus tolong bantuannya': 'Deactivating Jago savings on telephone numbers, synchronizing Gojek, GoPay plus accounts, please help',
#  'suka bank jago transfer bank gratis fitur kantong memudahkan mengatur keuangan sayangnya fitur pembayaran tagihan bpjs mohon fitur tagihan': 'I like Bank Jago, free bank transfers, the pocket feature makes it easier to manage finances, unfortunately the BPJS bill payment feature requires a billing feature',
#  'gak pake bank jago ribet buka aplikasi akun aja dibikin susah belagu banget pake bank aja yg user friendly': "Don't use a good bank, it's complicated to open the account application, it's really difficult to use a bank that is user friendly",
#  'tidk login': 'not logged in',
#  'mantbbbb': 'mantbbbb',
#  'cocok': 'suitable',
#  'alhamdulillah peningkatan yg': 'Alhamdulillah the improvement',
#  'jakaria karia dana atm bni': 'jakaria karia BNI ATM funds',
#  'tolong hapus data jago karenakan prose pinjaman nya': 'Please delete Jago data due to the loan process',
#  'bagus banget aplikasi': 'really good application',
#  'senang kalo': 'happy if',
#  'terbaik untk': 'best for',
#  'menbantu': 'help',
#  'payah rto bayar tagihan telat': "It's a shame that RTO pays bills late",
#  'maav sy uinstal aplikasi jago sy fikir solusi': "I'm sorry I installed the application I'm good at thinking of a solution",
#  'mantappp': 'greatpp',
#  'pake bank jago bener dah ribed banget orang kehilangan nomer ganti nomer pake materai download dokumen macem udah tau kena musibah kehilangan hp otomatis nomer nya hilang bikin ribed bank jago bank aja ga gitu via by phone doang bantu arahin beres uninstal aja pake sea bank nya aja': "use a good bank, it's really bad, people lose their number, change the number, use a seal, download the document, you already know if you have an accident, lose your phone, the number is automatically lost, make a good bank, it's just a good bank, it's not like that via by phone, just help guide it to uninstall, just use the sea bank",
#  'slmt sore jago masuk tdk krn no hp yg daftar jago sdh hilang ganti no kemana yahh trm ksh': 'Good afternoon, did Jago come in or not because the cellphone number that was registered as Jago has disappeared, where can I change the number, thank you',
#  'bagus apk nya': 'the apk is good',
#  'jd pakai aplikasi inijd tolong hapus data sy': 'So use this application so please delete my data',
#  'rekening jago dibuka disuruh autentikasi faktor disuruh masukin nik diajukan tau nya': 'opened a jago account, asked to authenticate the factor, asked to enter the NIK, and asked to know',
#  'pelayanana ancur komplainan ga direspon': 'The service was ruined, complaints were not responded to',
#  'baguss': 'nice',
#  'login susah': 'Difficult to log in',
#  'bank jao jago udah akun jago karnakan hp rusak gani hp ga masuk ya': "Bank Jago Jago already has a Jago account because the cell phone is broken and the cell phone doesn't come in",
#  'percaya pengiriman cepat admin': 'Trust admin fast delivery',
#  'kemitraan jago gopay diputus aja sumpah gak mending kemitraan ovo aja kalo kemitraan gopay udah putus akun terhubung gopay tabungan otomatis terputus tunggu kemitra gopay jago diputus kemitraan ovo': "Gopay's Jago partnership is just terminated, I swear it's not better to just have an OVO partnership. If the GoPay partnership has been terminated, the account connected to Gopay savings will automatically be terminated, wait for the GoPay Jago partnership to be terminated by OVO.",
#  'b mendapatka limit pinjaman bank jago': 'b get the loan limit from a good bank',
#  'kak akun sayah lupa ngimna': 'Sis, I forgot to create an account',
#  'lupa password x tf rek akun dikunci ferifikasi susah saldo jt hilang ga dipake bos': 'forgot password',
#  'masuk pasword ditolak email ditolak penipuan data': 'login password rejected email rejected data fraud',
#  'hati aplikasi penipu berkedok bank coba menerima gaji pt apkdri perusahaan status bukti perusahaan jg masuk tpi aplikasi saldo tr': 'Be careful, fraudulent applications under the guise of banks are trying to receive salaries from PT APKDRI, the status of the company proof is also entered but the balance application is tr',
#  'jago the best': 'jago the best',
#  'pakai bank jago untungnyamakin transaksi untungnya': 'Using a good bank will make your transactions more profitable',
#  'program promo²nya beneran mantaaap bank jago': 'the promo2 program is really good',
#  'jagoan': 'ace',
#  'bagus banget aplikasi nya': 'the application is really good',
#  'mudah bintang bintang': 'easy star star',
#  'jago mudah cepat': 'good, easy, fast',
#  'bang jago mohon perbaiki akun terkunci uang k didalam nya duit tabungan tolong bang jago kunci akun orang kocak': 'Bro, great, please fix the locked account, I have money in it, savings money, please, Bro, lock the account of a funny person',
#  'maaf perangkat hubungkan kendala menghubungkan perangkat login solusi hubungi c nya muter muter suruh isi data lengkap alamat kandung anggota keluarga yg kk dll ribet gak bank yg ribet untung tarik gopay tarik saldo aja nya pindahin bank': "sorry the device is connecting, there is a problem connecting the login device, the solution is to call C, it's going around and around, tell me to fill in the complete data, the biological address of the family member, etc. Isn't it complicated, isn't the bank complicated? Profitable to withdraw GoPay, just withdraw the balance, just switch banks.",
#  'bayar paylater lupa akun bayar gimana bos': 'pay paylater forgot how to pay account boss',
#  'nice': 'nice',
#  'sayangkan biaya kekurangan saldo pembayaran starlink kecewa': 'Unfortunately, the Starlink payment balance fee is disappointing',
#  'gampang gratis isi gopayshopeepay lumayan mudah belanja online': "It's easy and free to fill in Gopayshopeepay. It's quite easy to shop online",
#  'mudah menerima membayar tagihan negeri': 'easy to accept paying state bills',
#  'sy ganti nomor telpon nomor hilangtidak aktif daftar nik nyangkut akun terimakasih': 'I changed my phone number, lost number, inactive, nik list, account stuck, thank you',
#  'pengalaman bank jago kendala transaksi apapun pemberitahuan berjaga jaga saran bunga tabungan simpanan deposito dipotong pajak simpanan melebihi juta bank digital': "Bank's experience is good at dealing with any transaction problems, alerts, advice, interest on savings, deposits, tax deductible, deposits exceeding millions of digital banks",
#  'terbaik pokoknya': 'the best anyway',
#  'verifikasi langkah yg ga masuk akal': "verification steps that don't make sense",
#  'kk pake daftar gak login pin pasword salah': 'Sis, using data, not logging in, wrong pin password',
#  'keren bonus': 'return bonus',
#  'excellent iztimewa': 'excellent iztimewa',
#  'bintang berbicara': 'talking stars',
#  'unblockir debit card aja ampun': 'Just unblock the debit card, sorry',
#  'aplikasi peningkatan sistem': 'system upgrade application',
#  'aplikasi keren': 'cool app',
#  'màntapp': 'cover',
#  'rekening kalinya membayar k nomor rekening jago terbaca kirim uang rekening costumer service wa jawabannya lamban banget cakcek c shopee pengguna jago keluhan keluhan': 'account time to pay k jago account number legible send money account customer service wa the answer is really slow cakcek c shopee jago users complaints complaints',
#  'alhamdulillah masiih dpt dipercaya utk transaksi': 'Thank God it can still be trusted for transactions',
#  'fitur pinjaman dana': 'fund loan feature',
#  'aplikasi membantu': 'helpful app',
#  'mentransfer rekening rekening bank jago uang masuk rekening bank jago sayaternyata transfer dr rekening akun ovo melakukantidak etikat bank jago mengembalikan uang hilang': 'transferring my jago bank account, the money went into my jago bank account, it turned out that the transfer from the ovo account was not done properly, jago bank returned the lost money',
#  'verivikasi aktifasiii bngt': 'really active verification',
#  'semoga email akun beneran diganti prosesnya sat set alhamdullillah akun rekeningku aman lancar jaya': 'I hope the real account email will be replaced by the complete process. Thank God, my account is safe and running smoothly',
#  'keren': 'keren',
#  'suka pake': 'like to use',
#  'amanah': 'trust',
#  'membantu skli bank jago kartu atmnya langsung kirim': 'Helping the bank to be good at sending the ATM card straight away',
#  'parah banget turun peringkat jagoan kemarin silver loh aah male bedanya ama bank': "It's really bad that the ranking of yesterday's champion Silver fell, aah, male. What's the difference between banks?",
#  'susah ga acc': "it's hard to acc",
#  'mayan': 'mayan',
#  'bagus sekalidah snagat mudah gunakanbanyak kegunaanya': 'Very good, very easy to use, lots of uses',
#  'mntap': 'mntap',
#  'kode nya ok wasalam': 'the code is ok, thanks',
#  'akun buka blokir hubungi c nya suruh nunggu bertahap via email minggu loh nunggu hasilnya nihil gak pesan masuk email uang tabungan juta akun bank jago gak buka blokir trus uang tabungan apain tolong bank jago gitu costumer': "Unblock the account, contact C, tell them to wait in stages via email, a week, wait for the result to no avail, the message will not come in, the email will save millions, the bank account is good, it won't be unblocked, then what kind of savings, please, the bank is good, that's it, customer.",
#  'ribet banget kalo isi saldo uwang gak setir tunai langsung jagodan gak pengisian saldo alfaindo': "It's really complicated if you top up your balance without depositing cash straight away and don't top up your Alfaindo balance",
# ...
#  'membantu transfer mudah semoga bank jago sukses amin': 'helps with easy transfers, hopefully the bank will be successful, amen',
#  'wihhh kereennn k bang jago terimakasih bang jago': "Wow, that's cool, bro, you're good, thank you, bro, you're good",
#  'dihapus lupa nama kantongnya transaksi transaksi memasukkan nik data pribadi orang': "deleted, forgot the name of the pocket transaction, entered the person's personal data ID",
#  'aplikasi payah udah daftar nya disuruh verifikasi trus masuk lg gak padaha sandi nya udah': "The application sucks, I've registered, I'm told to verify it, then I can't log in even though I have the password",
#  'hati kalo nomer hp terblokir akun jago buka': 'Be careful if your cellphone number is blocked, your account will be good at opening it',
#  'puas pelayanan nya': 'satisfied with the service',
#  'alhamdulillah k pengguna heheh': 'Thank God for users heheh',
#  'bank online yg bagusbnyak reward': 'A good online bank has lots of rewards',
#  'bagustapi tarik tunai kartu gak yaa': 'Yes, but you can withdraw cash from your card',
#  'serius aplikasi transaksi cepat nih jago sat set banget transaksi nabung aman banget terima kasih devoloper apk jago': 'Seriously, this fast transaction application is really good at setting, savings transactions are really safe, thank you, Devoloper APK is great',
#  'info bantuan ya donk min gk login no yg terdaftar bana solusi nya': "info for help, sir, can't login to the number listed but there's a solution",
#  'bagusss': 'nice',
#  'emang apps bang jago emang hebat': "It's really a great app, bro",
#  'semoga putaran': 'hopefully round',
#  'nyusahin aja pa login pake hape dipersulit udah verifikasi nik email no handphone mengecewakan': "It's a hassle to log in using your phone, it's complicated, you've already verified your email and mobile number, it's disappointing",
#  'bank jago emang jago sukses': 'Good banks are really good at success',
#  'gada minor² aplikasi saran perbanyak atm bank jago nya setor tunai': 'Gada minor² application for advice on increasing number of bank ATMs which are good at making cash deposits',
#  'masuk susahpadahal pengguna gopay': "It's difficult to log in even though you're a GoPay user",
#  'gak ribet susah regis pengen vc': "It's not complicated, it's hard to register and want a VC",
#  'aplikasi ribet c amanah kirim berkas sesuai prosedur detik respon mohon dihapus dataku ya jago': 'Complicated application, trustworthy, send files according to procedure, second response, please delete my data, good guy',
#  'mempermudah pembayaransip deh': 'makes payments easier',
#  'aplikasi burik': 'dotted application',
#  'jago emg jagoan the best pinjaman mudah cicilan ringan byk bonus ny': "I'm really good at the best loans, easy installments, lots of bonuses",
#  'ribet bgt cok masuk hp yg jagonya rusak gimana masuk gk hafal bikin nik no telp email udh kepake': "It's really complicated, how to enter a cellphone that's broken, how to enter, don't remember how to make a nik, telephone number, email, already used",
#  'tgl uninstal aplikasi inikarena daftar aplikasi buka sekalikatanya gangguanmasa gangguan trssaya hapus data data sayaapabila salahgunakan bertanggung jawabdan lanjuti jalur hukumterima kasih bank jago': 'the date of uninstalling this application because the application list was opened once it said there was interference, then the interference occurred, I deleted my data, if misused, be responsible and follow the legal route, thank you Bank Jago',
#  'tolong tambahin fitur pilih galeri ktp kartu tanda penduduk barang kali pengguna akun membawa ktp': 'Please add a feature to select the identity card ID card gallery whenever the account user carries an ID card',
#  'akun saa ga dibuka ga login didalam uang nya aplikasi dana': "My account wasn't opened, I didn't log in to the money fund application",
#  'login karna hp yg ilang eh persulit haduh': 'logging in to a lost cellphone card is difficult, ouch',
#  'yaaa': 'yeah',
#  'hp dicopet login susah udah login pake device verifikasi device bank aja verifikasi pakai ktp selfie face regonition serumit semahal ya bank jago sistem nasabah memiliki kendala': 'cellphone was stolen login was difficult already logged in using device verify bank device just verify using ID card selfie face recognition is as complicated as expensive yes bank is good customer system has problems',
#  'mw ganti no hp gmn nya no hp': 'How can I change my cellphone number?',
#  'verifikasi wajah berhasil tp login selfi apk blom berfungsi': "Face verification was successful but Selfi APK login didn't work",
#  'cepat aman terpercaya': 'fast safe reliable',
#  'bank jago sekedar nama': 'good bank in name only',
#  'mntulll bngt': 'really helpful',
#  'lemot banget top up saldo gopay tp buffering sampe skrng saldo masukmasuk': "It's really slow to top up your GoPay balance but it's buffering until now the balance comes in",
#  'sulit': 'difficult',
#  'bang jago syariah gk potongan loh menurutku fiturnya aja bank kartu fisik pulaudah gitu pembayaran internasional mantap bank jago bisnis mudah': 'bro, good at sharia, no deductions, in my opinion, just the features of the island physical card bank are like that, international payments are great, bank is good at easy business',
#  'mempermudah membayar zakat': 'make it easier to pay zakat',
#  'aneh': 'Strange',
#  'bank ribet kalo suruh telpon fungsi email whatsapp benerbener membantu balas bot bikin susah nasabah kalo lupa keamanan login suruh telpon': 'the bank is complicated if they tell you to call, the WhatsApp email function really helps reply to bots, it makes it difficult for customers, if they forget the security login, they tell them to call',
#  'bank digital terbaik': 'best digital bank',
#  'udah setahun bug nama bahasa bahasa inggris settingan bahasa indonesia transaksi dihari rabu diresi tertera selasa transaksi malam pagi diperbaiki udah laporan via email': "It's been a year since the bug, name, English, Indonesian language settings, transaction on Wednesday, receipt says Tuesday, morning transaction, corrected, reported via email",
#  'so far aman sih semoga sukses bank jago': "So far it's safe, good luck with the good bank",
#  'kak gmna klau lupa pasword tpi no hp aktif lgi': 'Sis, what if you forget your password but your cellphone number is active again?',
#  'aplikasi nih gaje bgt sumpah masuk aja super duper ribet udah ganti password ga langsung masuk disuruh teka teki gak ujian sono sekolah yg bikin aplikasi bikin pusing kepala orangcocoknya kasih rating bintang': "This application is really fun, I swear just logging in is super duper complicated, I changed the password, I didn't enter straight away, I was asked to do a puzzle, didn't I take a school exam, which made the application give people a headache, it's better to give a star rating",
#  'pakai memudahkan bertransaksi aplikasi ekosistemnya terintegrasi gopay kekurangannya improve topup saldo kantong dipermudah menambah opsi pembayaran minimarket pengoptimalan aplikasi server minim crash eror aplikasinya customer service nya ok fast respon overall ok banget': 'use makes it easier to make transactions, the ecosystem application is integrated with Gopay, the downside is that improving top up of pocket balance makes it easier to add minimarket payment options, server application optimization, minimal application crashes, customer service is ok, fast response, overall really ok',
#  'mantapss aplikasi bank jago pemakaian mudah transfer ewallet danaovo gopay bank bonus rb promo jagoan adventure pengguna langsung masuk rekening terimakasih bank jago the best': 'greatss bank jago application easy use ewallet transfer danaovo gopay bank bonus rb promo jagoan adventure user directly enters account thank you bank jago the best',
#  'bulannya saldo masuk lumayan hooh': 'the month the balance comes in is quite good, hooh',
#  'tolong verifikasi langkah nya ubah menyusahkan orang login hp nya baruhp rusak verifikasi langkah diganti verifikasi muka sesuai ktp terdaftarkode otp': 'please verify the steps, change it makes it difficult for people to log in, their cellphone is broken, verify the steps, replace it, verify the face according to the registered ID card, OTP code',
#  'semoga pinjaman': 'hopefully a loan',
#  'kurangnya banya dalah na tdk pay later': 'The lack of money means not paying later',
#  'limit pinjaman jujur sih ragu': "To be honest, I'm doubtful about the loan limit",
#  'aplikasi bagus kendala aplikasi lemot mohon ditingkatkan': 'good application, slow application problem, please improve it',
#  'aplikasi jago membantu bertransaksi menabung investasi tolong bank jago tambahkan fitur valas biar menabung mata uang asing terimakasih': 'Jago application helps with transactions to save investment. Please Bank Jago add a foreign exchange feature to save foreign currency, thank you',
#  'tolong udah setahun gak masuk aplikasi bank jago pdhal password username dipersulit masuknya verifikasi langkah': "Please, it's been a year since I entered the Bank Jaja application, even though the username and password made it difficult to enter the verification steps",
#  'bank jago ok hadiah saldonya gratis transfer ewalet': 'Jago Bank, OK, the balance prize is free e-wallet transfer',
#  'pelayanan nya buruk': 'the service is bad',
#  'terimakasih bank jago nya mudah transaksi perbankan': 'Thank you, good bank for easy banking transactions',
#  'd tolak': 'd refuse',
#  'min tolong loginya otp aja pa suruh pertanyaansaya berbeda salah': "Min, please just OTP the logo, tell me if my question is different, it's wrong",
#  'hp hack orang data no hp email direset password bgmn solusinya ya': "cellphone hacked, someone's cellphone number data, email password reset, what's the solution?",
#  'eror nya penanganan': 'error handling',
#  'jagoemang terpecaya': 'reliable winner',
#  'maaf kasih rating kecewa banget transaksi pulsa senin jam bener bener cashback masuk rb udah x kena prank sih hati hati aja promo kadang boongan doang': "Sorry for giving the rating, really disappointed, credit transaction on Monday, cashback really came in Rp. I've been pranked, just be careful, promotions are sometimes just fake",
#  'aplikasi gk masak mw daftar aj bilang email no hp udh terdaftar maaf klw gitu uninstall bye': "the application doesn't work, just register, it says email, cellphone number already registered, sorry if that's the case, uninstall bye",
#  'bank rusak transfer sea bank duit gua ga masuk² saldo jago terpotong transaksi sukses': "The bank was damaged, the sea bank transfer, my money didn't arrive, my balance was interrupted, the transaction was successful",
#  'seandainya aja paylater syariah': 'If only the paylater was sharia',
#  'transaksional saldo minus transfer bank saldonya masuk kali': 'transactional balance minus bank transfer the balance goes in',
#  'mudah gratisnya bertransaksi': 'easy free transactions',
#  'ngehe masuk aja ribet banget nanya lupa password aja rese': "Wow, just logging in, it's really complicated, just ask if you forgot the password, just ask",
#  'apk payahgimna peminat nya layanan persetujuan login aja ribet': "The apk sucks, but if you're interested, the login approval service is complicated",
#  'kasih bintang transaksi dinyatakan sukses saldo kepotong dana nya masuk rekening penerima ganti bintang karna saldo dikembalikan bank jago terima kasih pengembalian dana nya minggu saldo': "give a star, the transaction was declared successful, the balance was deducted, the funds went into the recipient's account, replaced the star because the balance was returned, Jaja Bank, thank you for the refund, the balance was Sunday",
#  'mantul': 'helpful',
#  'nomer udah gak aktif nomer hilang ganti nomer verifikasi nya ribet pakai materai tolong dipermudah bank laen gak seribet dah': "the number is no longer active, the number is lost, change the verification number, it's complicated, use stamps, please make it easier, other banks don't have to worry about it.",
#  'jelek pembelian gagal limit jelek banget': 'bad purchase failed limit, really bad',
#  'keren sih bank jago nih': "It's cool how good a bank is",
#  'daftar gopay tabungan by jago tp setalah download jagonya daftar gx nyambung gopay gopay nyambung jago aneh udah gtu daftar ribet selfi ktp emang pinjol ngak ahhh ribet enak gopay': "register for Gopay savings by Jago, but after downloading Jago, the list can't connect, Gopay, Gopay connect, Jago is strange, that's it, registering is complicated, taking selfies, ID cards, is it really a loan or not, ahhh, it's complicated, delicious, Gopay",
#  'tolong pinjaman': 'loan please',
#  'bank gimanasih kecewa pelayanan penarikan uang atm uang saldo potong uang rb hilang kabar lapor email chat dll jjga prose biaya penarikan mahal butuh uang sulit kalo sperti berenti transaksi bank kalo sperti kapok': "how can the bank be disappointed with the ATM money withdrawal service, balance money cut off rb money, lost news, report email chat, etc. Also the withdrawal fee process is expensive, it's hard to make money, if you like, stop bank transactions if you've given up",
#  'aplikasi penipu gakusa didownload transaksi transfer uang bank penerima menerima uangnya alias gak masuk tp saldo jado telag terpotong laporan via email nunggu sampe berharihari uang ku raib gak dikembalikan menyesal sya jago gak ikhlas smpe hti kiamat uang ambil': "the fraudulent application doesn't download the money transfer transaction, the recipient's bank receives the money, aka it doesn't come in, but the balance has been deducted, the report via email has been waiting for days, my money has disappeared, it hasn't been returned, I'm sorry, I'm good at not being sincere, until the end of the world, the money is taken",
#  'memudahkan banget bertransaksi': 'makes transactions very easy',
#  'sungguh memuaskan': 'really satisfying',
#  'terimakasih bankjago layanan cepat': 'thank you bankjago fast service',
#  'pelayanan nasabah sang buruk bilangnya sebentar dihubungi sebentar nyata nya menghubungi pergantian no tlp kadaluarsa hilang pasword lupa otomatis kode otp nomor hilang': 'the customer service is bad, they say they will call for a while, in fact they will call to change their expired telephone number, lost password, automatically forgotten OTP code, number lost',
#  'melakunan top up pulsa pulsa kunjung masuk saldo terpotong kirim bukti suruh nunggu bang jago sampah': 'carry out the top up of credit, the credit arrives, the balance is deducted, send proof, tell me to wait, trash master',
#  'udah akun nomer nya hangus password nya lupa gimana masuk nya ya tolong bantuan nya': 'The account number has been forfeited, the password has been lost, I forgot how to log in, please help',
#  'ribet persamaan data yg susah udah lupa karna akun udah ditinggal tuk tutup akun musti persamaan data yg udah lupa pakai opsi meng aktifkan akun daftar yg bersangkutan yg nik jga terbantu buang uang beli materai pernyataan buang uang telpon cc nya makasih bantuannya yg membantu': "It's complicated to match the data, it's difficult, I forgot because the account has been abandoned, to close the account, I have to match the data that I forgot, use the option to activate the account, register in question, it's also helpful, waste of money, buy statement stamps, waste of money, call CC, thanks for your help, it's helpful",
#  'aplikasi co transfer eror mulu': 'the co transfer application keeps having errors',
#  'kecewa bank jago daftar bsknya buka aplikasinya gangguan': "Disappointed, the bank is good at registering but can't open the application, it's a problem",
#  'aplikasi gak errormana udah masukin data jugaingat uninstal aplikasi kalo data salah bertanggung': "The application doesn't error when you enter the data. Also remember to uninstall the application if the data is incorrect, you are responsible",
#  'error menampilkan data transaksi': 'error displays transaction data',
#  'mantapppp': 'greatpppp',
#  ...}

# %%
data.replace(translations, inplace = True)
data
# Out:
#                                    content_normalisasi2
# 0                                most errors are afraid
# 1     It's good that you have logged in for a while ...
# 2                      A good bank is really a good one
# 3     professional settlement of accounts taken over...
# 4                                                  good
# ...                                                 ...
# 4352  cool, good bank with the best service, it feel...
# 4353                                   easy manufacture
# 4354  downloading the seed top up application is blo...
# 4355                      helpful dn easy easy features
# 4356                                    steady and safe
#
# [4357 rows x 1 columns]

# %%
data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTranslated.xlsx', index=False)

# %%
#SPLIT DATA
import pandas as pd

dataset = pd.read_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTranslated.xlsx')

# Hitung jumlah baris dalam dataset
num_rows = len(dataset)

# Hitung jumlah baris yang akan digunakan sebagai pelatihan (disini 50%)
train_size = int(0.5 * num_rows)

# Bagi dataset menjadi subset pelatihan dan pengujian
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Simpan subset pelatihan ke dalam file xlsx
train_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTrainEnglish.xlsx', index=False)

# Simpan subset pengujian ke dalam file xlsx
test_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTestEnglish.xlsx', index=False)

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.11/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.11/dist-packages (from Textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.1->Textblob) (4.67.1)

# %%
from textblob import TextBlob

# %%
train_data
# Out:
#                                    content_normalisasi2
# 0                                most errors are afraid
# 1     It's good that you have logged in for a while ...
# 2                      A good bank is really a good one
# 3     professional settlement of accounts taken over...
# 4                                                  good
# ...                                                 ...
# 2173                                      good behavior
# 2174  It's really bad, bro, the reason is that the s...
# 2175                                       good service
# 2176                gx application for loan application
# 2177                                             social
#
# [2178 rows x 1 columns]

# %%
data_content = list(train_data['content_normalisasi2'])
polaritas = 0

status = []
total_positif = total_negatif = total = 0

for i, tweet in enumerate(data_content):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')
    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 1096
# Negatif = 1082
#
# Total Data : 2178

# %%
status = pd.DataFrame({'Label': status})
train_data['Label'] = status
train_data
# Out:
# <ipython-input-17-ddb1f5b9bf00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Label'] = status
#                                    content_normalisasi2    Label
# 0                                most errors are afraid  Negatif
# 1     It's good that you have logged in for a while ...  Positif
# 2                      A good bank is really a good one  Positif
# 3     professional settlement of accounts taken over...  Positif
# 4                                                  good  Positif
# ...                                                 ...      ...
# 2173                                      good behavior  Positif
# 2174  It's really bad, bro, the reason is that the s...  Negatif
# 2175                                       good service  Positif
# 2176                gx application for loan application  Negatif
# 2177                                             social  Positif
#
# [2178 rows x 2 columns]

# %%
# Memisahkan data berdasarkan label
positif_data = train_data[train_data['Label'] == 'Positif']
negatif_data = train_data[train_data['Label'] == 'Negatif']

# %%
# Menentukan jumlah sampel minimum di 2 kelas kelas
min_samples = min(total_positif, total_negatif)

# %%
from sklearn.utils import resample

# %%
# Melakukan penyeimbangan data dengan undersampling
positif_data_resampled = resample(positif_data, replace=False, n_samples=min_samples, random_state=42)
negatif_data_resampled = resample(negatif_data, replace=False, n_samples=min_samples, random_state=42)

# %%
# Menggabungkan kembali data yang telah disusun ulang
balanced_data = pd.concat([positif_data_resampled, negatif_data_resampled])

# %%
data_content_balanced = list(balanced_data['content_normalisasi2'])
polaritas_balanced = 0

status_balanced = []
total_positif_balanced = total_negatif_balanced = total_balanced = 0

for i, tweet in enumerate(data_content_balanced):
    analysis = TextBlob(tweet)
    polaritas_balanced += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif_balanced += 1
        status_balanced.append('Positif')
    else:
        total_negatif_balanced += 1
        status_balanced.append('Negatif')

    total_balanced += 1

print(f'Hasil Analisis Data Setelah Penyeimbangan:\nPositif = {total_positif_balanced}\nNegatif = {total_negatif_balanced}')
print(f'\nTotal Data Setelah Penyeimbangan: {total_balanced}')
# Out:
# Hasil Analisis Data Setelah Penyeimbangan:
# Positif = 1082
# Negatif = 1082
#
# Total Data Setelah Penyeimbangan: 2164

# %%
train_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTrainEngLabeled.xlsx',index=False)

# %%
balanced_data.to_excel('/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTrainEngLabeledBalanced.xlsx', index=False)

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTrainEngLabeledBalanced.xlsx'
output_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTrainIdnLabeledBalanced.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content_normalisasi2'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
# Out:
# Translation complete. Translated data saved to a new Excel file!

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTestEnglish.xlsx'
output_file = '/content/drive/MyDrive/Sentimen Analisis 3 Top Bank Digital/Jago_DataTestIndo.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content_normalisasi2'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
